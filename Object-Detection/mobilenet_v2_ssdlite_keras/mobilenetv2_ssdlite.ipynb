# %%
# !vi ~/.keras/keras.json

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
from tensorflow.python.client import device_lib
import tensorflow as tf

print("GPU Available: ", tf.test.is_gpu_available())

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print('GPU is available')

# %%
# %cd /root/mobilenet_v2_ssdlite_keras
# Out:
# /root/mobilenet_v2_ssdlite_keras

# %%
import sys
sys.path.append('/root/mobilenet_v2_ssdlite_keras')

# %%
from __future__ import division
import os
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from losses.keras_ssd_loss import SSDLoss
from utils.object_detection_2d_data_generator import DataGenerator
from utils.object_detection_2d_geometric_ops import Resize
from utils.object_detection_2d_photometric_ops import ConvertTo3Channels
from utils.data_augmentation_chain_original_ssd import SSDDataAugmentation
from utils.coco import get_coco_category_maps
from utils.ssd_input_encoder import SSDInputEncoder
# from models.keras_mobilenet_v2_ssdlite import mobilenet_v2_ssd
from layers.AnchorBoxesLayer import AnchorBoxes
from layers.DecodeDetectionsLayer import DecodeDetections
from layers.DecodeDetectionsFastLayer import DecodeDetectionsFast
from models.graphs.mobilenet_v2_ssdlite_praph import mobilenet_v2_ssdlite
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Input, Lambda, Activation, Conv2D, \
    DepthwiseConv2D, Reshape, Concatenate, BatchNormalization, ReLU
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from glob import glob
from tensorflow import keras
# Out:
# 2021-12-07 01:07:20.127052: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# tf.debugging.set_log_device_placement(True)

# %% [markdown]
# # OID txt TO XML

# %% [markdown]
# ## 1.conver_annotation

# %%
# %cd /root/OIDv4_ToolKit/

# %%
len(glob('/root/OIDv4_ToolKit/OID/Dataset/train/Hat/*.jpg'))

# %%
len(glob('/root/OIDv4_ToolKit/OID/Dataset/train/Helmet/*.jpg'))

# %%
# !python /root/OIDv4_ToolKit/convert_annotations.py

# %% [markdown]
# ## 2. txt to xml

# %%
pwd

# %%
# %cd /root/OIDv4_ToolKit/

# %%
ls

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/train/Hat\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/train_annotation/

# %%
from glob import glob

# %%
# xml 파일 갯수
print(len(glob('/root/OIDv4_ToolKit/OID/Dataset/train_annotation/*.xml')))
# txt 파일 갯수
print(len(glob('/root/OIDv4_ToolKit/OID/Dataset/train/Hat/Label/*.txt')))

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/train/Helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/train_annotation/

# %%
# xml 파일 갯수
print(len(glob('/root/OIDv4_ToolKit/OID/Dataset/train_annotation/*.xml'))\
     -len(glob('/root/OIDv4_ToolKit/OID/Dataset/train/Helmet/Label/*.txt')))

# txt 파일 갯수
print(len(glob('/root/OIDv4_ToolKit/OID/Dataset/train/Helmet/Label/*.txt')))

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/train/Bicycle_helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/train_annotation/

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/train/Human_head\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/train_annotation/

# %%
print(len(glob('/root/OIDv4_ToolKit/OID/Dataset/train_annotation/*.xml')))

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/test/Hat\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/test_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/test/Helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/test_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/test/Bicycle_helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/test_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/test/Human_head\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/test_annotation/

# %%
# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/validation/Hat\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/validation_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/validation/Helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/validation_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/validation/Bicycle_helmet\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/validation_annotation/

# !python3 OIDv4_to_VOC.py\
--sourcepath /root/OIDv4_ToolKit/OID/Dataset/validation/Human_head\
--dest_path /root/OIDv4_ToolKit/OID/Dataset/validation_annotation/

# %% [markdown]
# ## 이미지 폴더 통합

# %%
from tqdm import tqdm
import os
for i in tqdm(['train', 'test', 'validation']):
    for j in ['Bicycle_helmet', 'Hat', 'Helmet', 'Human_head']:
        for k in glob(f'/root/OIDv4_ToolKit/OID/Dataset/{i}/{j}/*.txt'):
            os.remove(k)

# %%
from tqdm import tqdm
import shutil
for i in tqdm(['train', 'test', 'validation']):
    for j in ['Bicycle_helmet', 'Hat', 'Helmet', 'Human_head']:
        for k in glob(f'/root/OIDv4_ToolKit/OID/Dataset/{i}/{j}/*.jpg'):
            shutil.copyfile(k, f'/root/OIDv4_ToolKit/OID/Dataset/{i}_all/{k.split("/")[-1]}')

# %%
for i in tqdm(['train', 'test', 'validation']):
    with open(f'/root/OIDv4_ToolKit/OID/Dataset/{i}.txt', 'w') as f: 
        for k in glob(f'/root/OIDv4_ToolKit/OID/Dataset/{i}_all/*.jpg'):
            f.write(k.split('/')[-1].split('.')[0] + '\n')

# %% [markdown]
# # model_config

# %%
K.clear_session()

# %%
# model config
batch_size = 1024
image_size = (300, 300, 3)
n_classes = 4
mode = 'training'
l2_regularization = 0.0005
min_scale = 0.1
max_scale = 0.9
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05]
scales = scales_pascal
aspect_ratios_global = None
aspect_ratios  = [[1.0, 2.0, 0.5], 
                [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0], 
                [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0], 
                [1.0, 2.0, 0.5], 
                [1.0, 2.0, 0.5]]
two_boxes_for_ar1 = True
steps = None
offsets = None
clip_boxes = False
variances = [0.1, 0.1, 0.2, 0.2]

# %% [markdown]
# ### learning_rate

# %%
# # learning rate
# def lr_schedule(epoch):
#     if epoch < 200:
#         return 0.0001
#     elif epoch < 500:
#         return 0.00005
#     else:
#         return 0.00001

# %% [markdown]
# ### 훈련 가능한 레이블 설정

# %%
# set trainable layers
def set_trainable(layer_regex, keras_model=None, indent=0, verbose=1):
    # In multi-GPU training, we wrap the model. Get layers
    # of the inner model because they have the weights.
    layers = keras_model.inner_model.layers if hasattr(keras_model, "inner_model") \
        else keras_model.layers

    for layer in layers:
        # Is the layer a model?
        if layer.__class__.__name__ == 'Model':
            print("In model: ", layer.name)
            set_trainable(
                layer_regex, keras_model=layer)
            continue

        if not layer.weights:
            continue
        # Is it trainable?
        trainable = bool(re.fullmatch(layer_regex, layer.name))
        # Update layer. If layer is a container, update inner layer.
        if layer.__class__.__name__ == 'TimeDistributed':
            layer.layer.trainable = trainable
        else:
            layer.trainable = trainable
        # Print trainable layer names
        if trainable and verbose > 0:
            print("{}{:20}   ({})".format(" " * indent, layer.name, layer.__class__.__name__))

# %% [markdown]
# ### predict_block

# %%
def predict_block(inputs, out_channel, sym, id):
    name = 'ssd_' + sym + '{}'.format(id)
    x = DepthwiseConv2D(kernel_size=3, strides=1,
                           activation=None, use_bias=False, padding='same', name=name + '_dw_conv')(inputs)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=name + '_dw_bn')(x)
    x = ReLU(6., name=name + '_dw_relu')(x)

    x = Conv2D(out_channel, kernel_size=1, padding='same', use_bias=False,
                  activation=None, name=name + 'conv2')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=name + 'conv2_bn')(x)
    return x

# %% [markdown]
# ### model

# %%
def mobilenet_v2_ssd(image_size,
            n_classes,
            mode='training',
            l2_regularization=0.0005,
            min_scale=None,
            max_scale=None,
            scales=None,
            aspect_ratios_global=None,
            aspect_ratios_per_layer=aspect_ratios,
            two_boxes_for_ar1=True,
            steps=[8, 16, 32, 64, 100, 300],
            offsets=None,
            clip_boxes=False,
            variances=[0.1, 0.1, 0.2, 0.2],
            coords='centroids',
            normalize_coords=True,
            subtract_mean=[123, 117, 104],
            divide_by_stddev=None,
            swap_channels=[2, 1, 0],
            confidence_thresh=0.01,
            iou_threshold=0.45,
            top_k=100,
            nms_max_output_size=400,
            return_predictor_sizes=False):
   

    n_predictor_layers = 6  # The number of predictor conv layers in the network is 6 for the original SSD300.
    n_classes += 1  # Account for the background class.
    l2_reg = l2_regularization  # Make the internal name shorter.
    img_height, img_width, img_channels = image_size[0], image_size[1], image_size[2]

    ############################################################################
    # Get a few exceptions out of the way.
    ############################################################################

    if aspect_ratios_global is None and aspect_ratios_per_layer is None:
        raise ValueError(
            "`aspect_ratios_global` and `aspect_ratios_per_layer` \
            cannot both be None. At least one needs to be specified.")
    if aspect_ratios_per_layer:
        if len(aspect_ratios_per_layer) != n_predictor_layers:
            raise ValueError(
                "It must be either aspect_ratios_per_layer is None or len(aspect_ratios_per_layer) == {}, \
                but len(aspect_ratios_per_layer) == {}.".format(
                    n_predictor_layers, len(aspect_ratios_per_layer)))

    if (min_scale is None or max_scale is None) and scales is None:
        raise ValueError("Either `min_scale` and `max_scale` or `scales` need to be specified.")
    if scales:
        if len(scales) != n_predictor_layers + 1:
            raise ValueError("It must be either scales is None or len(scales) == {}, but len(scales) == {}.".format(
                n_predictor_layers + 1, len(scales)))
    # If no explicit list of scaling factors was passed,
    # compute the list of scaling factors from `min_scale` and `max_scale`
    else:
        scales = np.linspace(min_scale, max_scale, n_predictor_layers + 1)

    if len(variances) != 4:
        raise ValueError("4 variance values must be pased, but {} values were received.".format(len(variances)))
    variances = np.array(variances)
    if np.any(variances <= 0):
        raise ValueError("All variances must be >0, but the variances given are {}".format(variances))

    if (not (steps is None)) and (len(steps) != n_predictor_layers):
        raise ValueError("You must provide at least one step value per predictor layer.")

    if (not (offsets is None)) and (len(offsets) != n_predictor_layers):
        raise ValueError("You must provide at least one offset value per predictor layer.")

    ############################################################################
    # Compute the anchor box parameters.
    ############################################################################

    # Set the aspect ratios for each predictor layer. These are only needed for the anchor box layers.
    if aspect_ratios_per_layer:
        aspect_ratios = aspect_ratios_per_layer
    else:
        aspect_ratios = [aspect_ratios_global] * n_predictor_layers
    print("여기")
    # Compute the number of boxes to be predicted per cell for each predictor layer.
    # We need this so that we know how many channels the predictor layers need to have.
    if aspect_ratios_per_layer:
        n_boxes = []
        for ar in aspect_ratios_per_layer:
            if (1 in ar) & two_boxes_for_ar1:
                n_boxes.append(len(ar) + 1)  # +1 for the second box for aspect ratio 1
            else:
                n_boxes.append(len(ar))
    # If only a global aspect ratio list was passed,
    # then the number of boxes is the same for each predictor layer
    else:
        if (1 in aspect_ratios_global) & two_boxes_for_ar1:
            n_boxes = len(aspect_ratios_global) + 1
        else:
            n_boxes = len(aspect_ratios_global)
        n_boxes = [n_boxes] * n_predictor_layers

    if steps is None:
        steps = [None] * n_predictor_layers
    if offsets is None:
        offsets = [None] * n_predictor_layers

    ############################################################################
    # Define functions for the Lambda layers below.
    ############################################################################

    def identity_layer(tensor):
        return tensor

    def input_mean_normalization(tensor):
        return tensor - np.array(subtract_mean)

    def input_stddev_normalization(tensor):
        return tensor / np.array(divide_by_stddev)

    def input_channel_swap(tensor):
        if len(swap_channels) == 3:
            return K.stack(
                [tensor[..., swap_channels[0]], tensor[..., swap_channels[1]], tensor[..., swap_channels[2]]], axis=-1)
        elif len(swap_channels) == 4:
            return K.stack([tensor[..., swap_channels[0]], tensor[..., swap_channels[1]], tensor[..., swap_channels[2]],
                            tensor[..., swap_channels[3]]], axis=-1)

    ############################################################################
    # Build the network.
    ############################################################################

    x = Input(shape=(img_height, img_width, img_channels))

    # The following identity layer is only needed so that the subsequent lambda layers can be optional.
    x1 = Lambda(identity_layer, output_shape=(img_height, img_width, img_channels), name='identity_layer')(x)

    tmp_shape = K.int_shape(x1)

    if not (subtract_mean is None):
        x1 = Lambda(input_mean_normalization, output_shape=(img_height, img_width, img_channels),
                    name='input_mean_normalization')(x1)
    if not (divide_by_stddev is None):
        x1 = Lambda(input_stddev_normalization, output_shape=(img_height, img_width, img_channels),
                    name='input_stddev_normalization')(x1)
    if swap_channels:
        x1 = Lambda(
            input_channel_swap, output_shape=(img_height, img_width, img_channels), name='input_channel_swap')(x1)

    links = mobilenet_v2_ssdlite(x1)

    link1_cls = predict_block(links[0], n_boxes[0] * n_classes, 'cls', 1)
    link2_cls = predict_block(links[1], n_boxes[1] * n_classes, 'cls', 2)
    link3_cls = predict_block(links[2], n_boxes[2] * n_classes, 'cls', 3)
    link4_cls = predict_block(links[3], n_boxes[3] * n_classes, 'cls', 4)
    link5_cls = predict_block(links[4], n_boxes[4] * n_classes, 'cls', 5)
    link6_cls = predict_block(links[5], n_boxes[5] * n_classes, 'cls', 6)

    link1_box = predict_block(links[0], n_boxes[0] * 4, 'box', 1)
    link2_box = predict_block(links[1], n_boxes[1] * 4, 'box', 2)
    link3_box = predict_block(links[2], n_boxes[2] * 4, 'box', 3)
    link4_box = predict_block(links[3], n_boxes[3] * 4, 'box', 4)
    link5_box = predict_block(links[4], n_boxes[4] * 4, 'box', 5)
    link6_box = predict_block(links[5], n_boxes[5] * 4, 'box', 6)
    print("여기2")
    priorbox1 = AnchorBoxes(img_height, img_width, this_scale=scales[0], next_scale=scales[1],
                                             aspect_ratios=aspect_ratios[0],
                                             two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[0],
                                             this_offsets=offsets[0], clip_boxes=clip_boxes,
                                             variances=variances, coords=coords, normalize_coords=normalize_coords,
                                             name='ssd_priorbox_1')(link1_box)
    priorbox2 = AnchorBoxes(img_height, img_width, this_scale=scales[1], next_scale=scales[2],
                                    aspect_ratios=aspect_ratios[1],
                                    two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[1], this_offsets=offsets[1],
                                    clip_boxes=clip_boxes,
                                    variances=variances, coords=coords, normalize_coords=normalize_coords,
                                    name='ssd_priorbox_2')(link2_box)
    priorbox3 = AnchorBoxes(img_height, img_width, this_scale=scales[2], next_scale=scales[3],
                                        aspect_ratios=aspect_ratios[2],
                                        two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[2],
                                        this_offsets=offsets[2], clip_boxes=clip_boxes,
                                        variances=variances, coords=coords, normalize_coords=normalize_coords,
                                        name='ssd_priorbox_3')(link3_box)
    priorbox4 = AnchorBoxes(img_height, img_width, this_scale=scales[3], next_scale=scales[4],
                                        aspect_ratios=aspect_ratios[3],
                                        two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[3],
                                        this_offsets=offsets[3], clip_boxes=clip_boxes,
                                        variances=variances, coords=coords, normalize_coords=normalize_coords,
                                        name='ssd_priorbox_4')(link4_box)
    priorbox5 = AnchorBoxes(img_height, img_width, this_scale=scales[4], next_scale=scales[5],
                                        aspect_ratios=aspect_ratios[4],
                                        two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[4],
                                        this_offsets=offsets[4], clip_boxes=clip_boxes,
                                        variances=variances, coords=coords, normalize_coords=normalize_coords,
                                        name='ssd_priorbox_5')(link5_box)
    priorbox6 = AnchorBoxes(img_height, img_width, this_scale=scales[5], next_scale=scales[6],
                                        aspect_ratios=aspect_ratios[5],
                                        two_boxes_for_ar1=two_boxes_for_ar1, this_steps=steps[5],
                                        this_offsets=offsets[5], clip_boxes=clip_boxes,
                                        variances=variances, coords=coords, normalize_coords=normalize_coords,
                                        name='ssd_priorbox_6')(link6_box)

    # Reshape
    cls1_reshape = Reshape((-1, n_classes), name='ssd_cls1_reshape')(link1_cls)
    cls2_reshape = Reshape((-1, n_classes), name='ssd_cls2_reshape')(link2_cls)
    cls3_reshape = Reshape((-1, n_classes), name='ssd_cls3_reshape')(link3_cls)
    cls4_reshape = Reshape((-1, n_classes), name='ssd_cls4_reshape')(link4_cls)
    cls5_reshape = Reshape((-1, n_classes), name='ssd_cls5_reshape')(link5_cls)
    cls6_reshape = Reshape((-1, n_classes), name='ssd_cls6_reshape')(link6_cls)

    box1_reshape = Reshape((-1, 4), name='ssd_box1_reshape')(link1_box)
    box2_reshape = Reshape((-1, 4), name='ssd_box2_reshape')(link2_box)
    box3_reshape = Reshape((-1, 4), name='ssd_box3_reshape')(link3_box)
    box4_reshape = Reshape((-1, 4), name='ssd_box4_reshape')(link4_box)
    box5_reshape = Reshape((-1, 4), name='ssd_box5_reshape')(link5_box)
    box6_reshape = Reshape((-1, 4), name='ssd_box6_reshape')(link6_box)

    priorbox1_reshape = Reshape((-1, 8), name='ssd_priorbox1_reshape')(priorbox1)
    priorbox2_reshape = Reshape((-1, 8), name='ssd_priorbox2_reshape')(priorbox2)
    priorbox3_reshape = Reshape((-1, 8), name='ssd_priorbox3_reshape')(priorbox3)
    priorbox4_reshape = Reshape((-1, 8), name='ssd_priorbox4_reshape')(priorbox4)
    priorbox5_reshape = Reshape((-1, 8), name='ssd_priorbox5_reshape')(priorbox5)
    priorbox6_reshape = Reshape((-1, 8), name='ssd_priorbox6_reshape')(priorbox6)
    print("여기3")

    cls = Concatenate(axis=1, name='ssd_cls')(
        [cls1_reshape, cls2_reshape, cls3_reshape, cls4_reshape, cls5_reshape, cls6_reshape])

    box = Concatenate(axis=1, name='ssd_box')(
        [box1_reshape, box2_reshape, box3_reshape, box4_reshape, box5_reshape, box6_reshape])

    priorbox = Concatenate(axis=1, name='ssd_priorbox')(
        [priorbox1_reshape, priorbox2_reshape, priorbox3_reshape,
         priorbox4_reshape, priorbox5_reshape, priorbox6_reshape])
    
    print(priorbox.shape)
    cls = Activation('softmax', name='ssd_mbox_conf_softmax')(cls)
    print("여기4")
    predictions = Concatenate(axis=2, name='ssd_predictions')([cls, box, priorbox])

    if mode == 'training':
        model = Model(inputs=x, outputs=predictions)
    elif mode == 'inference':
        decoded_predictions = DecodeDetections(confidence_thresh=confidence_thresh,
                                               iou_threshold=iou_threshold,
                                               top_k=top_k,
                                               nms_max_output_size=nms_max_output_size,
                                               coords=coords,
                                               normalize_coords=normalize_coords,
                                               img_height=img_height,
                                               img_width=img_width,
                                               name='ssd_decoded_predictions')(predictions)
        model = Model(inputs=x, outputs=decoded_predictions)
    elif mode == 'inference_fast':
        decoded_predictions = DecodeDetectionsFast(confidence_thresh=confidence_thresh,
                                                   iou_threshold=iou_threshold,
                                                   top_k=top_k,
                                                   nms_max_output_size=nms_max_output_size,
                                                   coords=coords,
                                                   normalize_coords=normalize_coords,
                                                   img_height=img_height,
                                                   img_width=img_width,
                                                   name='ssd_decoded_predictions')(predictions)
        model = Model(inputs=x, outputs=decoded_predictions)
    else:
        raise ValueError(
            "`mode` must be one of 'training', 'inference' or 'inference_fast', but received '{}'.".format(mode))

    if return_predictor_sizes:
        predictor_sizes = np.array(
            [cls[0]._keras_shape[1:3], cls[1]._keras_shape[1:3], cls[2]._keras_shape[1:3],
             cls[3]._keras_shape[1:3], cls[4]._keras_shape[1:3], cls[5]._keras_shape[1:3]])
        print("return_predictor_sizes")
        return model, predictor_sizes
    else:
        print("모델 리턴")
        return model

# %% [markdown]
# ### 모델 빌드

# %%
# build model
model = mobilenet_v2_ssd(image_size, 
                         n_classes, 
                         mode, 
                         l2_regularization,
                         min_scale, 
                         max_scale, 
                         scales,
                         aspect_ratios_global, 
                         aspect_ratios,
                        # aspect_ratios_per_layer, 
                         two_boxes_for_ar1, 
                         steps,
                         offsets, 
                         clip_boxes, 
                         variances, 
                        #  coords, 
                        #  normalize_coords, 
                        #  subtract_mean,
                        #  divide_by_stddev, 
                        #  swap_channels, 
                        #  confidence_thresh, 
                        #  iou_threshold, 
                        #  top_k,
                        #  nms_max_output_size, 
                        #  return_predictor_sizes
                         )
# Out:
# 여기
# 2021-12-07 01:07:51.535264: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-07 01:07:51.537396: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-07 01:07:52.057099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.057956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-12-07 01:07:52.057999: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-07 01:07:52.062095: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-07 01:07:52.062224: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-07 01:07:52.063965: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-07 01:07:52.064421: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-07 01:07:52.068675: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-07 01:07:52.069688: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-07 01:07:52.069927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-07 01:07:52.070086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.070999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.071772: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-07 01:07:52.072837: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-07 01:07:52.074786: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-07 01:07:52.075003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.075806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-12-07 01:07:52.075846: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-07 01:07:52.075883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-07 01:07:52.075902: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-07 01:07:52.075919: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-07 01:07:52.075936: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-07 01:07:52.075953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-07 01:07:52.075971: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-07 01:07:52.075989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-07 01:07:52.076092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.076973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.077779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-07 01:07:52.077847: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-07 01:07:52.887437: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-07 01:07:52.887483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-12-07 01:07:52.887494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-12-07 01:07:52.887843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.888922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.889824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-07 01:07:52.890618: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14760 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 여기2
# 여기3
# (None, 2268, 8)
# 여기4
# 모델 리턴

# %%
import gc
gc.collect()

# %% [markdown]
# ### 옵티마이저, 손실 함수

# %%
adam = Adam(learning_rate=0.001)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

# %% [markdown]
# ### 모델 컴파일

# %%
model.compile(optimizer=adam, loss=ssd_loss.compute_loss, metrics = ['acc'])

# %% [markdown]
# ### 재학습시 모델 로드

# %%
path = "/root/mobilenet_v2_ssdlite_keras/checkpoint.h5"

model =load_model(
   path, custom_objects={"AnchorBoxes":AnchorBoxes},  compile = False)


adam = Adam(learning_rate=0.01)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss, metrics=['acc'])

# %% [markdown]
# ### 데이터 준비 및 로드

# %%
# 데이터 로드
train_dataset = DataGenerator()
val_dataset = DataGenerator()

# %%
train_images_dir = '/root/OIDv4_ToolKit/OID/Dataset/train_all/'
train_annotations_dir = '/root/OIDv4_ToolKit/OID/Dataset/train_annotation/'
train_image_set_filename = '/root/OIDv4_ToolKit/OID/Dataset/train.txt'


test_images_dir = '/root/OIDv4_ToolKit/OID/Dataset/test_all/'
test_annotations_dir = '/root/OIDv4_ToolKit/OID/Dataset/test_annotation/'
test_image_set_filename     = '/root/OIDv4_ToolKit/OID/Dataset/test.txt'


validation_images_dir = '/root/OIDv4_ToolKit/OID/Dataset/validation_all/'
validation_annotations_dir = '/root/OIDv4_ToolKit/OID/Dataset/validation_annotation/'
validation_image_set_filename     = '/root/OIDv4_ToolKit/OID/Dataset/validation.txt'

# %%
classes=['Hat', 'Helmet', 'Bicycle helmet', 'Human head']
# classes=['Hat']

# %%
import os
len(os.listdir('/root/OIDv4_ToolKit/OID/Dataset/train_annotation'))

# %%
len(os.listdir('/root/OIDv4_ToolKit/OID/Dataset/train_all'))

# %%
train_dataset.parse_xml(
                        images_dirs = [train_images_dir],
                        image_set_filenames = [train_image_set_filename],
                        annotations_dirs = [train_annotations_dir],
                        classes = classes,
                        include_classes = 'all',
                        exclude_truncated = False,
                        exclude_difficult = False,
                        ret = False
                        )


val_dataset.parse_xml(images_dirs = [validation_images_dir],
                      image_set_filenames = [validation_image_set_filename],
                      annotations_dirs = [validation_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=False,#used to be True
                      ret=False)
# Out:
# Processing image set 'train.txt': 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 38393/38393 [01:25<00:00, 449.61it/s]
# Processing image set 'validation.txt': 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 3530/3530 [00:06<00:00, 547.22it/s]

# %%
# train_dataset.create_hdf5_dataset(file_path='/root/mobilenet_v2_ssdlite_keras/train_dataset.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='/root/mobilenet_v2_ssdlite_keras/validation_dataset.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 #

# %%
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width)

# %%
# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
#用getlayer来获取输出层的尺寸
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('ssd_cls1conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls2conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls3conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls4conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls5conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls6conv2_bn').output_shape[1:3]]
#encoder把ground truth labels
ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=True)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],# used to be augumentation
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 38393
# Number of images in the validation dataset:	  3530

# %%
# a,b = next(train_generator)
# print(a.shape)
# a = np.expand_dims(a, axis=1)
# print(a.shape)

# %%
pwd

# %%
# 텐서보드
tb_hist = keras.callbacks.TensorBoard(log_dir='./graph',
                                      histogram_freq=0, 
                                      write_graph=True, 
                                      write_images=True)

# %%
K.clear_session()

# %%
initial_epoch   = 0
final_epoch     = 1000
# steps_per_epoch = 1 #1035#6000
steps_per_epoch = len(os.listdir('/root/OIDv4_ToolKit/OID/Dataset/train_all')) // batch_size
val_dataset_size = len(os.listdir('/root/OIDv4_ToolKit/OID/Dataset/validation_all'))

# Define model callbacks.
# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='checkpoint.h5',
                                   monitor='val_loss',#used to be val_loss
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   save_freq=int(batch_size * steps_per_epoch))
# int(batch_size * steps_per_epoch)
                                  
#model_checkpoint.best = 

csv_logger = CSVLogger(filename='MobileNetv2_ssdLite_training_log.csv',
                       separator=',',
                       append=True)

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
#                                                 verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             # learning_rate_scheduler,
             terminate_on_nan]
#              ,tb_hist]

# %%
# with tf.device('/device:GPU:0'):
with tf.device('/GPU:0'):
    history = model.fit(train_generator,
                        steps_per_epoch = steps_per_epoch,
                        epochs = final_epoch,
                        callbacks = callbacks,
                        validation_data = val_generator,
                        validation_steps = val_dataset_size//batch_size,
                        initial_epoch = initial_epoch,
                        verbose = 1)
# Out:
# 2021-12-07 01:11:31.906067: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-12-07 01:11:31.906760: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1999995000 Hz
# Epoch 1/1000
# Tensor("Neg:0", shape=(None, 2268), dtype=float32)
# 2021-12-07 01:11:41.572345: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-07 01:11:44.972290: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-07 01:11:45.771636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-07 01:11:55.773768: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.75GiB (rounded to 2949120000)requested by op model/bbn_stage1_block2_dw_bn/FusedBatchNormV3
# Current allocation summary follows.
# 2021-12-07 01:11:55.773849: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2021-12-07 01:11:55.773865: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 335, Chunks in use: 335. 83.8KiB allocated for chunks. 83.8KiB in use in bin. 28.3KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773879: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 198, Chunks in use: 197. 124.2KiB allocated for chunks. 123.8KiB in use in bin. 110.1KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773891: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 141, Chunks in use: 141. 176.8KiB allocated for chunks. 176.8KiB in use in bin. 172.5KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773902: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 147, Chunks in use: 147. 401.0KiB allocated for chunks. 401.0KiB in use in bin. 393.0KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773914: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 56, Chunks in use: 56. 296.8KiB allocated for chunks. 296.8KiB in use in bin. 283.6KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773925: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 48, Chunks in use: 48. 531.2KiB allocated for chunks. 531.2KiB in use in bin. 508.2KiB client-requested in use in bin.
# 2021-12-07 01:11:55.773936: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 52, Chunks in use: 52. 1.10MiB allocated for chunks. 1.10MiB in use in bin. 1.08MiB client-requested in use in bin.
# 2021-12-07 01:11:55.773947: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 35, Chunks in use: 35. 1.45MiB allocated for chunks. 1.45MiB in use in bin. 1.42MiB client-requested in use in bin.
# 2021-12-07 01:11:55.773957: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 26, Chunks in use: 26. 2.41MiB allocated for chunks. 2.41MiB in use in bin. 2.41MiB client-requested in use in bin.
# 2021-12-07 01:11:55.773968: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 31, Chunks in use: 31. 5.34MiB allocated for chunks. 5.34MiB in use in bin. 5.24MiB client-requested in use in bin.
# 2021-12-07 01:11:55.773978: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 6, Chunks in use: 6. 1.95MiB allocated for chunks. 1.95MiB in use in bin. 1.80MiB client-requested in use in bin.
# 2021-12-07 01:11:55.773990: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 18, Chunks in use: 18. 10.29MiB allocated for chunks. 10.29MiB in use in bin. 10.29MiB client-requested in use in bin.
# 2021-12-07 01:11:55.774001: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 9, Chunks in use: 9. 11.95MiB allocated for chunks. 11.95MiB in use in bin. 11.95MiB client-requested in use in bin.
# 2021-12-07 01:11:55.774011: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-12-07 01:11:55.774021: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-12-07 01:11:55.774033: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 2, Chunks in use: 2. 17.72MiB allocated for chunks. 17.72MiB in use in bin. 17.72MiB client-requested in use in bin.
# 2021-12-07 01:11:55.774044: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 17.72MiB allocated for chunks. 17.72MiB in use in bin. 17.72MiB client-requested in use in bin.
# 2021-12-07 01:11:55.774056: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 3, Chunks in use: 2. 115.17MiB allocated for chunks. 79.73MiB in use in bin. 79.73MiB client-requested in use in bin.
# 2021-12-07 01:11:55.774069: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-12-07 01:11:55.774079: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-12-07 01:11:55.774090: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 7, Chunks in use: 4. 14.23GiB allocated for chunks. 9.28GiB in use in bin. 9.28GiB client-requested in use in bin.
# 2021-12-07 01:11:55.774100: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 2.75GiB was 256.00MiB, Chunk State:
# 2021-12-07 01:11:55.774119: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 414.28MiB | Requested Size: 313.90MiB | in_use: 0 | bin_num: 20, prev:   Size: 256B | Requested Size: 4B | in_use: 1 | bin_num: -1, next:   Size: 8.86MiB | Requested Size: 8.86MiB | in_use: 1 | bin_num: -1
# 2021-12-07 01:11:55.774132: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 2.07GiB | Requested Size: 1.03GiB | in_use: 0 | bin_num: 20, prev:   Size: 8.86MiB | Requested Size: 8.86MiB | in_use: 1 | bin_num: -1, next:   Size: 1.04GiB | Requested Size: 1.04GiB | in_use: 1 | bin_num: -1
# 2021-12-07 01:11:55.774144: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 2.48GiB | Requested Size: 128B | in_use: 0 | bin_num: 20, prev:   Size: 2.75GiB | Requested Size: 2.75GiB | in_use: 1 | bin_num: -1
# 2021-12-07 01:11:55.774153: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 15477595136
# 2021-12-07 01:11:55.774181: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000000 of size 1280 next 1
# 2021-12-07 01:11:55.774190: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000500 of size 256 next 5
# 2021-12-07 01:11:55.774199: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000600 of size 256 next 8
# 2021-12-07 01:11:55.774206: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000700 of size 256 next 9
# 2021-12-07 01:11:55.774214: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000800 of size 256 next 10
# 2021-12-07 01:11:55.774222: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7ff3ec000900 of size 512 next 12
# 2021-12-07 01:11:55.774230: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000b00 of size 256 next 21
# 2021-12-07 01:11:55.774238: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000c00 of size 256 next 24
# 2021-12-07 01:11:55.774246: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000d00 of size 256 next 25
# 2021-12-07 01:11:55.774254: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000e00 of size 256 next 26
# 2021-12-07 01:11:55.774262: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec000f00 of size 256 next 28
# 2021-12-07 01:11:55.774270: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001000 of size 256 next 29
# 2021-12-07 01:11:55.774279: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001100 of size 512 next 2
# 2021-12-07 01:11:55.774286: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001300 of size 256 next 3
# 2021-12-07 01:11:55.774294: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001400 of size 256 next 4
# 2021-12-07 01:11:55.774302: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001500 of size 256 next 13
# 2021-12-07 01:11:55.774310: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001600 of size 256 next 14
# 2021-12-07 01:11:55.774318: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001700 of size 256 next 15
# 2021-12-07 01:11:55.774327: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001800 of size 256 next 17
# 2021-12-07 01:11:55.774335: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001900 of size 256 next 18
# 2021-12-07 01:11:55.774343: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001a00 of size 256 next 19
# 2021-12-07 01:11:55.774352: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001b00 of size 256 next 20
# 2021-12-07 01:11:55.774359: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001c00 of size 256 next 16
# 2021-12-07 01:11:55.774368: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec001d00 of size 1792 next 6
# 2021-12-07 01:11:55.774376: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec002400 of size 3584 next 7
# 2021-12-07 01:11:55.774384: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003200 of size 512 next 27
# 2021-12-07 01:11:55.774392: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003400 of size 512 next 32
# 2021-12-07 01:11:55.774400: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003600 of size 512 next 33
# 2021-12-07 01:11:55.774408: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003800 of size 256 next 35
# 2021-12-07 01:11:55.774416: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003900 of size 256 next 36
# 2021-12-07 01:11:55.774423: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003a00 of size 256 next 22
# 2021-12-07 01:11:55.774432: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec003b00 of size 2048 next 23
# 2021-12-07 01:11:55.774440: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004300 of size 512 next 34
# 2021-12-07 01:11:55.774447: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004500 of size 512 next 38
# 2021-12-07 01:11:55.774455: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004700 of size 512 next 39
# 2021-12-07 01:11:55.774463: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004900 of size 512 next 40
# 2021-12-07 01:11:55.774471: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004b00 of size 256 next 42
# 2021-12-07 01:11:55.774479: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004c00 of size 256 next 41
# 2021-12-07 01:11:55.774487: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004d00 of size 256 next 45
# 2021-12-07 01:11:55.774495: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004e00 of size 256 next 46
# 2021-12-07 01:11:55.774515: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec004f00 of size 256 next 47
# 2021-12-07 01:11:55.774523: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005000 of size 256 next 48
# 2021-12-07 01:11:55.774531: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005100 of size 256 next 49
# 2021-12-07 01:11:55.774539: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005200 of size 768 next 52
# 2021-12-07 01:11:55.774547: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005500 of size 768 next 53
# 2021-12-07 01:11:55.774555: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005800 of size 768 next 54
# 2021-12-07 01:11:55.774563: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005b00 of size 1024 next 37
# 2021-12-07 01:11:55.774571: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec005f00 of size 5120 next 31
# 2021-12-07 01:11:55.774580: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec007300 of size 6144 next 30
# 2021-12-07 01:11:55.774588: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec008b00 of size 5376 next 59
# 2021-12-07 01:11:55.774596: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00a000 of size 768 next 73
# 2021-12-07 01:11:55.774604: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00a300 of size 768 next 75
# 2021-12-07 01:11:55.774612: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00a600 of size 768 next 76
# 2021-12-07 01:11:55.774620: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00a900 of size 768 next 77
# 2021-12-07 01:11:55.774628: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00ac00 of size 256 next 78
# 2021-12-07 01:11:55.774636: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00ad00 of size 256 next 79
# 2021-12-07 01:11:55.774644: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00ae00 of size 256 next 82
# 2021-12-07 01:11:55.774652: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00af00 of size 256 next 83
# 2021-12-07 01:11:55.774660: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b000 of size 256 next 84
# 2021-12-07 01:11:55.774668: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b100 of size 256 next 85
# 2021-12-07 01:11:55.774676: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b200 of size 256 next 86
# 2021-12-07 01:11:55.774683: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b300 of size 256 next 87
# 2021-12-07 01:11:55.774691: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b400 of size 256 next 95
# 2021-12-07 01:11:55.774699: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b500 of size 256 next 74
# 2021-12-07 01:11:55.774707: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00b600 of size 7424 next 44
# 2021-12-07 01:11:55.774715: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00d300 of size 9216 next 43
# 2021-12-07 01:11:55.774723: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00f700 of size 768 next 58
# 2021-12-07 01:11:55.774731: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00fa00 of size 768 next 60
# 2021-12-07 01:11:55.774739: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec00fd00 of size 768 next 61
# 2021-12-07 01:11:55.774747: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010000 of size 768 next 62
# 2021-12-07 01:11:55.774755: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010300 of size 256 next 63
# 2021-12-07 01:11:55.774763: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010400 of size 256 next 66
# 2021-12-07 01:11:55.774771: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010500 of size 256 next 67
# 2021-12-07 01:11:55.774779: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010600 of size 256 next 68
# 2021-12-07 01:11:55.774787: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010700 of size 1280 next 55
# 2021-12-07 01:11:55.774795: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010c00 of size 256 next 56
# 2021-12-07 01:11:55.774803: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010d00 of size 256 next 57
# 2021-12-07 01:11:55.774810: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec010e00 of size 768 next 69
# 2021-12-07 01:11:55.774818: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec011100 of size 768 next 71
# 2021-12-07 01:11:55.774826: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec011400 of size 768 next 72
# 2021-12-07 01:11:55.774834: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec011700 of size 768 next 90
# 2021-12-07 01:11:55.774842: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec011a00 of size 768 next 91
# 2021-12-07 01:11:55.774851: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec011d00 of size 768 next 92
# 2021-12-07 01:11:55.774859: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec012000 of size 768 next 93
# 2021-12-07 01:11:55.774867: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec012300 of size 768 next 94
# 2021-12-07 01:11:55.774875: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec012600 of size 768 next 97
# 2021-12-07 01:11:55.774883: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec012900 of size 1024 next 51
# 2021-12-07 01:11:55.774891: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec012d00 of size 13824 next 50
# 2021-12-07 01:11:55.774899: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec016300 of size 1536 next 164
# 2021-12-07 01:11:55.774907: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec016900 of size 1536 next 165
# 2021-12-07 01:11:55.774915: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec016f00 of size 256 next 167
# 2021-12-07 01:11:55.774923: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017000 of size 256 next 168
# 2021-12-07 01:11:55.774931: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017100 of size 256 next 169
# 2021-12-07 01:11:55.774939: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017200 of size 256 next 170
# 2021-12-07 01:11:55.774947: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017300 of size 1536 next 172
# 2021-12-07 01:11:55.774954: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017900 of size 1536 next 173
# 2021-12-07 01:11:55.774962: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec017f00 of size 1536 next 174
# 2021-12-07 01:11:55.774970: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec018500 of size 1536 next 175
# 2021-12-07 01:11:55.774978: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec018b00 of size 512 next 220
# 2021-12-07 01:11:55.774986: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec018d00 of size 512 next 221
# 2021-12-07 01:11:55.774994: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec018f00 of size 512 next 222
# 2021-12-07 01:11:55.775002: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec019100 of size 512 next 223
# 2021-12-07 01:11:55.775010: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec019300 of size 2304 next 225
# 2021-12-07 01:11:55.775018: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec019c00 of size 2304 next 226
# 2021-12-07 01:11:55.775026: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec01a500 of size 2304 next 227
# 2021-12-07 01:11:55.775034: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec01ae00 of size 2304 next 228
# 2021-12-07 01:11:55.775042: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec01b700 of size 2304 next 229
# 2021-12-07 01:11:55.775050: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec01c000 of size 3840 next 65
# 2021-12-07 01:11:55.775058: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec01cf00 of size 13824 next 64
# 2021-12-07 01:11:55.775066: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec020500 of size 13824 next 70
# 2021-12-07 01:11:55.775074: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec023b00 of size 768 next 110
# 2021-12-07 01:11:55.775081: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec023e00 of size 768 next 112
# 2021-12-07 01:11:55.775089: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024100 of size 768 next 113
# 2021-12-07 01:11:55.775097: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024400 of size 768 next 114
# 2021-12-07 01:11:55.775106: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024700 of size 256 next 116
# 2021-12-07 01:11:55.775114: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024800 of size 256 next 117
# 2021-12-07 01:11:55.775122: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024900 of size 256 next 118
# 2021-12-07 01:11:55.775130: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024a00 of size 256 next 119
# 2021-12-07 01:11:55.775138: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024b00 of size 768 next 121
# 2021-12-07 01:11:55.775146: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec024e00 of size 768 next 122
# 2021-12-07 01:11:55.775154: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec025100 of size 768 next 123
# 2021-12-07 01:11:55.775162: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec025400 of size 768 next 111
# 2021-12-07 01:11:55.775181: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec025700 of size 11264 next 81
# 2021-12-07 01:11:55.775189: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec028300 of size 18432 next 80
# 2021-12-07 01:11:55.775197: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02cb00 of size 6912 next 96
# 2021-12-07 01:11:55.775205: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02e600 of size 768 next 98
# 2021-12-07 01:11:55.775213: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02e900 of size 256 next 101
# 2021-12-07 01:11:55.775221: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02ea00 of size 256 next 102
# 2021-12-07 01:11:55.775229: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02eb00 of size 256 next 103
# 2021-12-07 01:11:55.775236: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02ec00 of size 256 next 104
# 2021-12-07 01:11:55.775244: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02ed00 of size 768 next 106
# 2021-12-07 01:11:55.775252: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02f000 of size 768 next 107
# 2021-12-07 01:11:55.775260: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02f300 of size 768 next 108
# 2021-12-07 01:11:55.775268: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02f600 of size 768 next 109
# 2021-12-07 01:11:55.775276: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02f900 of size 1536 next 150
# 2021-12-07 01:11:55.775285: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec02ff00 of size 256 next 153
# 2021-12-07 01:11:55.775300: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030000 of size 256 next 154
# 2021-12-07 01:11:55.775315: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030100 of size 256 next 155
# 2021-12-07 01:11:55.775326: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030200 of size 256 next 156
# 2021-12-07 01:11:55.775337: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030300 of size 1536 next 158
# 2021-12-07 01:11:55.775347: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030900 of size 1536 next 159
# 2021-12-07 01:11:55.775357: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec030f00 of size 1536 next 160
# 2021-12-07 01:11:55.775367: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec031500 of size 1536 next 161
# 2021-12-07 01:11:55.775377: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec031b00 of size 1536 next 162
# 2021-12-07 01:11:55.775388: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec032100 of size 2560 next 89
# 2021-12-07 01:11:55.775399: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec032b00 of size 24576 next 88
# 2021-12-07 01:11:55.775409: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec038b00 of size 768 next 124
# 2021-12-07 01:11:55.775420: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec038e00 of size 768 next 127
# 2021-12-07 01:11:55.775430: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039100 of size 768 next 128
# 2021-12-07 01:11:55.775441: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039400 of size 768 next 129
# 2021-12-07 01:11:55.775456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039700 of size 256 next 131
# 2021-12-07 01:11:55.775472: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039800 of size 256 next 132
# 2021-12-07 01:11:55.775484: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039900 of size 256 next 130
# 2021-12-07 01:11:55.775493: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039a00 of size 256 next 135
# 2021-12-07 01:11:55.775513: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039b00 of size 256 next 136
# 2021-12-07 01:11:55.775521: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039c00 of size 256 next 137
# 2021-12-07 01:11:55.775529: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039d00 of size 256 next 138
# 2021-12-07 01:11:55.775537: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039e00 of size 256 next 139
# 2021-12-07 01:11:55.775545: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec039f00 of size 2048 next 125
# 2021-12-07 01:11:55.775553: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03a700 of size 6912 next 126
# 2021-12-07 01:11:55.775561: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03c200 of size 1536 next 142
# 2021-12-07 01:11:55.775569: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03c800 of size 1536 next 143
# 2021-12-07 01:11:55.775576: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03ce00 of size 1536 next 144
# 2021-12-07 01:11:55.775584: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03d400 of size 256 next 146
# 2021-12-07 01:11:55.775592: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03d500 of size 256 next 147
# 2021-12-07 01:11:55.775600: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03d600 of size 1536 next 145
# 2021-12-07 01:11:55.775608: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03dc00 of size 1536 next 149
# 2021-12-07 01:11:55.775616: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03e200 of size 2304 next 100
# 2021-12-07 01:11:55.775624: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec03eb00 of size 24576 next 99
# 2021-12-07 01:11:55.775632: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec044b00 of size 24576 next 105
# 2021-12-07 01:11:55.775640: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec04ab00 of size 24576 next 115
# 2021-12-07 01:11:55.775648: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec050b00 of size 24576 next 120
# 2021-12-07 01:11:55.775655: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec056b00 of size 13824 next 148
# 2021-12-07 01:11:55.775663: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05a100 of size 13824 next 163
# 2021-12-07 01:11:55.775671: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05d700 of size 1536 next 176
# 2021-12-07 01:11:55.775679: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05dd00 of size 1536 next 179
# 2021-12-07 01:11:55.775687: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05e300 of size 1536 next 180
# 2021-12-07 01:11:55.775695: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05e900 of size 1536 next 181
# 2021-12-07 01:11:55.775704: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05ef00 of size 256 next 183
# 2021-12-07 01:11:55.775712: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05f000 of size 256 next 184
# 2021-12-07 01:11:55.775720: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05f100 of size 256 next 185
# 2021-12-07 01:11:55.775728: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05f200 of size 256 next 186
# 2021-12-07 01:11:55.775736: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05f300 of size 1536 next 188
# 2021-12-07 01:11:55.775744: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05f900 of size 1536 next 189
# 2021-12-07 01:11:55.775752: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec05ff00 of size 1536 next 190
# 2021-12-07 01:11:55.775760: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec060500 of size 2304 next 177
# 2021-12-07 01:11:55.775768: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec060e00 of size 13824 next 178
# 2021-12-07 01:11:55.775776: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec064400 of size 1536 next 191
# 2021-12-07 01:11:55.775784: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec064a00 of size 1536 next 194
# 2021-12-07 01:11:55.775791: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec065000 of size 1536 next 195
# 2021-12-07 01:11:55.775799: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec065600 of size 1536 next 196
# 2021-12-07 01:11:55.775807: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec065c00 of size 256 next 198
# 2021-12-07 01:11:55.775815: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec065d00 of size 256 next 199
# 2021-12-07 01:11:55.775823: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec065e00 of size 512 next 197
# 2021-12-07 01:11:55.775831: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066000 of size 512 next 202
# 2021-12-07 01:11:55.775839: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066200 of size 512 next 203
# 2021-12-07 01:11:55.775854: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066400 of size 512 next 204
# 2021-12-07 01:11:55.775867: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066600 of size 256 next 205
# 2021-12-07 01:11:55.775878: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066700 of size 256 next 206
# 2021-12-07 01:11:55.775890: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec066800 of size 2304 next 209
# 2021-12-07 01:11:55.775901: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec067100 of size 2560 next 192
# 2021-12-07 01:11:55.775912: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec067b00 of size 13824 next 193
# 2021-12-07 01:11:55.775926: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06b100 of size 2304 next 210
# 2021-12-07 01:11:55.775942: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06ba00 of size 2304 next 211
# 2021-12-07 01:11:55.775953: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06c300 of size 256 next 213
# 2021-12-07 01:11:55.775961: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06c400 of size 256 next 214
# 2021-12-07 01:11:55.775969: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06c500 of size 2304 next 212
# 2021-12-07 01:11:55.775977: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06ce00 of size 2304 next 217
# 2021-12-07 01:11:55.775985: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06d700 of size 2304 next 218
# 2021-12-07 01:11:55.775993: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06e000 of size 2816 next 134
# 2021-12-07 01:11:55.776002: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec06eb00 of size 49152 next 133
# 2021-12-07 01:11:55.776011: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07ab00 of size 2304 next 231
# 2021-12-07 01:11:55.776019: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07b400 of size 2304 next 232
# 2021-12-07 01:11:55.776027: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07bd00 of size 512 next 234
# 2021-12-07 01:11:55.776035: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07bf00 of size 512 next 235
# 2021-12-07 01:11:55.776042: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07c100 of size 512 next 236
# 2021-12-07 01:11:55.776050: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07c300 of size 512 next 237
# 2021-12-07 01:11:55.776058: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07c500 of size 2304 next 239
# 2021-12-07 01:11:55.776066: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07ce00 of size 2304 next 240
# 2021-12-07 01:11:55.776074: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07d700 of size 2304 next 241
# 2021-12-07 01:11:55.776082: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07e000 of size 2304 next 242
# 2021-12-07 01:11:55.776089: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07e900 of size 2304 next 245
# 2021-12-07 01:11:55.776097: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07f200 of size 2560 next 230
# 2021-12-07 01:11:55.776106: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec07fc00 of size 20736 next 216
# 2021-12-07 01:11:55.776113: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec084d00 of size 20736 next 215
# 2021-12-07 01:11:55.776121: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec089e00 of size 3840 next 262
# 2021-12-07 01:11:55.776129: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08ad00 of size 256 next 263
# 2021-12-07 01:11:55.776137: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08ae00 of size 256 next 264
# 2021-12-07 01:11:55.776145: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08af00 of size 3840 next 267
# 2021-12-07 01:11:55.776153: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08be00 of size 3840 next 268
# 2021-12-07 01:11:55.776161: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08cd00 of size 3840 next 269
# 2021-12-07 01:11:55.776182: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08dc00 of size 3840 next 270
# 2021-12-07 01:11:55.776190: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08eb00 of size 768 next 272
# 2021-12-07 01:11:55.776198: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08ee00 of size 768 next 273
# 2021-12-07 01:11:55.776206: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08f100 of size 768 next 274
# 2021-12-07 01:11:55.776214: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08f400 of size 768 next 275
# 2021-12-07 01:11:55.776222: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec08f700 of size 3840 next 277
# 2021-12-07 01:11:55.776230: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec090600 of size 3840 next 278
# 2021-12-07 01:11:55.776238: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec091500 of size 5632 next 141
# 2021-12-07 01:11:55.776247: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec092b00 of size 98304 next 140
# 2021-12-07 01:11:55.776255: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0aab00 of size 2304 next 246
# 2021-12-07 01:11:55.776263: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ab400 of size 2304 next 247
# 2021-12-07 01:11:55.776271: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0abd00 of size 256 next 249
# 2021-12-07 01:11:55.776279: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0abe00 of size 256 next 250
# 2021-12-07 01:11:55.776287: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0abf00 of size 768 next 248
# 2021-12-07 01:11:55.776295: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ac200 of size 768 next 253
# 2021-12-07 01:11:55.776302: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ac500 of size 768 next 254
# 2021-12-07 01:11:55.776310: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ac800 of size 768 next 255
# 2021-12-07 01:11:55.776318: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0acb00 of size 256 next 256
# 2021-12-07 01:11:55.776326: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0acc00 of size 256 next 257
# 2021-12-07 01:11:55.776334: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0acd00 of size 3840 next 260
# 2021-12-07 01:11:55.776342: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0adc00 of size 3840 next 261
# 2021-12-07 01:11:55.776350: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0aeb00 of size 4352 next 244
# 2021-12-07 01:11:55.776358: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0afc00 of size 20736 next 243
# 2021-12-07 01:11:55.776366: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b4d00 of size 256 next 322
# 2021-12-07 01:11:55.776374: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b4e00 of size 256 next 323
# 2021-12-07 01:11:55.776382: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b4f00 of size 1024 next 324
# 2021-12-07 01:11:55.776390: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b5300 of size 1024 next 327
# 2021-12-07 01:11:55.776398: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b5700 of size 1024 next 328
# 2021-12-07 01:11:55.776406: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b5b00 of size 1024 next 329
# 2021-12-07 01:11:55.776421: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b5f00 of size 256 next 330
# 2021-12-07 01:11:55.776434: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b6000 of size 256 next 331
# 2021-12-07 01:11:55.776446: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b6100 of size 2048 next 333
# 2021-12-07 01:11:55.776456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b6900 of size 2816 next 325
# 2021-12-07 01:11:55.776468: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b7400 of size 9216 next 326
# 2021-12-07 01:11:55.776479: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b9800 of size 256 next 343
# 2021-12-07 01:11:55.776495: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b9900 of size 256 next 344
# 2021-12-07 01:11:55.776521: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b9a00 of size 512 next 345
# 2021-12-07 01:11:55.776529: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b9c00 of size 512 next 348
# 2021-12-07 01:11:55.776537: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0b9e00 of size 512 next 349
# 2021-12-07 01:11:55.776545: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ba000 of size 512 next 350
# 2021-12-07 01:11:55.776553: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ba200 of size 256 next 352
# 2021-12-07 01:11:55.776561: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ba300 of size 256 next 353
# 2021-12-07 01:11:55.776569: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ba400 of size 1024 next 351
# 2021-12-07 01:11:55.776578: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0ba800 of size 1280 next 346
# 2021-12-07 01:11:55.776586: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bad00 of size 4608 next 347
# 2021-12-07 01:11:55.776594: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bbf00 of size 1024 next 369
# 2021-12-07 01:11:55.776602: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bc300 of size 1024 next 370
# 2021-12-07 01:11:55.776610: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bc700 of size 1024 next 371
# 2021-12-07 01:11:55.776618: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bcb00 of size 256 next 373
# 2021-12-07 01:11:55.776626: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bcc00 of size 256 next 374
# 2021-12-07 01:11:55.776634: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bcd00 of size 256 next 372
# 2021-12-07 01:11:55.776642: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bce00 of size 256 next 376
# 2021-12-07 01:11:55.776650: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bcf00 of size 256 next 377
# 2021-12-07 01:11:55.776658: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bd000 of size 256 next 378
# 2021-12-07 01:11:55.776665: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bd100 of size 512 next 388
# 2021-12-07 01:11:55.776673: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bd300 of size 512 next 392
# 2021-12-07 01:11:55.776681: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bd500 of size 512 next 393
# 2021-12-07 01:11:55.776689: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bd700 of size 768 next 379
# 2021-12-07 01:11:55.776697: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bda00 of size 256 next 380
# 2021-12-07 01:11:55.776705: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bdb00 of size 256 next 381
# 2021-12-07 01:11:55.776712: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bdc00 of size 256 next 384
# 2021-12-07 01:11:55.776720: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bdd00 of size 256 next 385
# 2021-12-07 01:11:55.776728: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bde00 of size 256 next 386
# 2021-12-07 01:11:55.776736: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bdf00 of size 256 next 387
# 2021-12-07 01:11:55.776744: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0be000 of size 256 next 389
# 2021-12-07 01:11:55.776751: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0be100 of size 256 next 390
# 2021-12-07 01:11:55.776759: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0be200 of size 256 next 364
# 2021-12-07 01:11:55.776767: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0be300 of size 4608 next 363
# 2021-12-07 01:11:55.776775: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bf500 of size 2304 next 383
# 2021-12-07 01:11:55.776783: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0bfe00 of size 2304 next 382
# 2021-12-07 01:11:55.776791: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c0700 of size 2304 next 394
# 2021-12-07 01:11:55.776798: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c1000 of size 2304 next 396
# 2021-12-07 01:11:55.776806: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c1900 of size 2304 next 397
# 2021-12-07 01:11:55.776814: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2200 of size 256 next 399
# 2021-12-07 01:11:55.776822: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2300 of size 256 next 398
# 2021-12-07 01:11:55.776830: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2400 of size 256 next 401
# 2021-12-07 01:11:55.776838: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2500 of size 256 next 402
# 2021-12-07 01:11:55.776846: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2600 of size 256 next 403
# 2021-12-07 01:11:55.776853: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2700 of size 256 next 405
# 2021-12-07 01:11:55.776861: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2800 of size 256 next 406
# 2021-12-07 01:11:55.776869: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2900 of size 256 next 412
# 2021-12-07 01:11:55.776890: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2a00 of size 256 next 152
# 2021-12-07 01:11:55.776898: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0c2b00 of size 98304 next 151
# 2021-12-07 01:11:55.776906: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0dab00 of size 98304 next 157
# 2021-12-07 01:11:55.776914: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec0f2b00 of size 98304 next 166
# 2021-12-07 01:11:55.776922: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec10ab00 of size 98304 next 171
# 2021-12-07 01:11:55.776929: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec122b00 of size 98304 next 182
# 2021-12-07 01:11:55.776937: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec13ab00 of size 98304 next 187
# 2021-12-07 01:11:55.776946: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec152b00 of size 131072 next 354
# 2021-12-07 01:11:55.776954: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec172b00 of size 65536 next 375
# 2021-12-07 01:11:55.776967: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff3ec182b00 of size 5120 next 404
# ...
# 2021-12-07 01:11:55.787787: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7ff4118f5c00 of size 2219225088 next 1099
# 2021-12-07 01:11:55.787801: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff495d60c00 of size 1113305088 next 1098
# 2021-12-07 01:11:55.787813: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff4d831bc00 of size 2949120000 next 1110
# 2021-12-07 01:11:55.787828: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff587f9bc00 of size 2949120000 next 1109
# 2021-12-07 01:11:55.787840: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7ff637c1bc00 of size 2949120000 next 11
# 2021-12-07 01:11:55.787854: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7ff6e789bc00 of size 2667552768 next 18446744073709551615
# 2021-12-07 01:11:55.787868: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2021-12-07 01:11:55.787893: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 335 Chunks of size 256 totalling 83.8KiB
# 2021-12-07 01:11:55.787913: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 96 Chunks of size 512 totalling 48.0KiB
# 2021-12-07 01:11:55.787926: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 101 Chunks of size 768 totalling 75.8KiB
# 2021-12-07 01:11:55.787940: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 64 Chunks of size 1024 totalling 64.0KiB
# 2021-12-07 01:11:55.787955: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 14 Chunks of size 1280 totalling 17.5KiB
# 2021-12-07 01:11:55.787970: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 60 Chunks of size 1536 totalling 90.0KiB
# 2021-12-07 01:11:55.787988: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 1792 totalling 5.2KiB
# 2021-12-07 01:11:55.788002: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 27 Chunks of size 2048 totalling 54.0KiB
# 2021-12-07 01:11:55.788018: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 64 Chunks of size 2304 totalling 144.0KiB
# 2021-12-07 01:11:55.788034: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 2560 totalling 7.5KiB
# 2021-12-07 01:11:55.788051: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 2816 totalling 5.5KiB
# 2021-12-07 01:11:55.788068: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 3584 totalling 17.5KiB
# 2021-12-07 01:11:55.788083: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 46 Chunks of size 3840 totalling 172.5KiB
# 2021-12-07 01:11:55.788095: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4352 totalling 4.2KiB
# 2021-12-07 01:11:55.788113: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 11 Chunks of size 4608 totalling 49.5KiB
# 2021-12-07 01:11:55.788126: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4864 totalling 4.8KiB
# 2021-12-07 01:11:55.788141: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 24 Chunks of size 5120 totalling 120.0KiB
# 2021-12-07 01:11:55.788156: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 5376 totalling 26.2KiB
# 2021-12-07 01:11:55.788190: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 5632 totalling 11.0KiB
# 2021-12-07 01:11:55.788225: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 6144 totalling 12.0KiB
# 2021-12-07 01:11:55.788240: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 8 Chunks of size 6912 totalling 54.0KiB
# 2021-12-07 01:11:55.788254: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 7424 totalling 7.2KiB
# 2021-12-07 01:11:55.788267: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 7936 totalling 7.8KiB
# 2021-12-07 01:11:55.788280: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 8192 totalling 24.0KiB
# 2021-12-07 01:11:55.788292: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 8704 totalling 8.5KiB
# 2021-12-07 01:11:55.788306: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 18 Chunks of size 9216 totalling 162.0KiB
# 2021-12-07 01:11:55.788319: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 10240 totalling 30.0KiB
# 2021-12-07 01:11:55.788331: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 11264 totalling 22.0KiB
# 2021-12-07 01:11:55.788344: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 20 Chunks of size 13824 totalling 270.0KiB
# 2021-12-07 01:11:55.788358: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 15104 totalling 14.8KiB
# 2021-12-07 01:11:55.788371: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 16384 totalling 48.0KiB
# 2021-12-07 01:11:55.788384: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 9 Chunks of size 18432 totalling 162.0KiB
# 2021-12-07 01:11:55.788399: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 19200 totalling 18.8KiB
# 2021-12-07 01:11:55.788412: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 20480 totalling 60.0KiB
# 2021-12-07 01:11:55.788425: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 13 Chunks of size 20736 totalling 263.2KiB
# 2021-12-07 01:11:55.788438: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 23808 totalling 23.2KiB
# 2021-12-07 01:11:55.788452: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 24064 totalling 23.5KiB
# 2021-12-07 01:11:55.788466: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 17 Chunks of size 24576 totalling 408.0KiB
# 2021-12-07 01:11:55.788480: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 30720 totalling 90.0KiB
# 2021-12-07 01:11:55.788494: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 32000 totalling 31.2KiB
# 2021-12-07 01:11:55.788527: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 32768 totalling 96.0KiB
# 2021-12-07 01:11:55.788542: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 8 Chunks of size 34560 totalling 270.0KiB
# 2021-12-07 01:11:55.788554: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 36864 totalling 108.0KiB
# 2021-12-07 01:11:55.788570: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 10 Chunks of size 46080 totalling 450.0KiB
# 2021-12-07 01:11:55.788583: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 46336 totalling 45.2KiB
# 2021-12-07 01:11:55.788597: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 48384 totalling 47.2KiB
# 2021-12-07 01:11:55.788611: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 6 Chunks of size 49152 totalling 288.0KiB
# 2021-12-07 01:11:55.788625: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 61440 totalling 180.0KiB
# 2021-12-07 01:11:55.788639: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 65536 totalling 192.0KiB
# 2021-12-07 01:11:55.788652: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 20 Chunks of size 98304 totalling 1.88MiB
# 2021-12-07 01:11:55.788665: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 122880 totalling 360.0KiB
# 2021-12-07 01:11:55.788680: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 9 Chunks of size 131072 totalling 1.12MiB
# 2021-12-07 01:11:55.788697: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 145920 totalling 142.5KiB
# 2021-12-07 01:11:55.788713: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 147456 totalling 432.0KiB
# 2021-12-07 01:11:55.788725: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 153600 totalling 300.0KiB
# 2021-12-07 01:11:55.788741: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 206848 totalling 202.0KiB
# 2021-12-07 01:11:55.788753: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 15 Chunks of size 221184 totalling 3.16MiB
# 2021-12-07 01:11:55.788765: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 262144 totalling 256.0KiB
# 2021-12-07 01:11:55.788777: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 321024 totalling 313.5KiB
# 2021-12-07 01:11:55.788790: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 352256 totalling 344.0KiB
# 2021-12-07 01:11:55.788803: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 368640 totalling 1.05MiB
# 2021-12-07 01:11:55.788817: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 524288 totalling 1.50MiB
# 2021-12-07 01:11:55.788831: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 15 Chunks of size 614400 totalling 8.79MiB
# 2021-12-07 01:11:55.788843: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 1228800 totalling 3.52MiB
# 2021-12-07 01:11:55.788855: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 1310720 totalling 3.75MiB
# 2021-12-07 01:11:55.788867: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 1638400 totalling 4.69MiB
# 2021-12-07 01:11:55.788881: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 9289728 totalling 17.72MiB
# 2021-12-07 01:11:55.788897: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 18579456 totalling 17.72MiB
# 2021-12-07 01:11:55.788914: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 37158912 totalling 35.44MiB
# 2021-12-07 01:11:55.788928: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 46448640 totalling 44.30MiB
# 2021-12-07 01:11:55.788940: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1113305088 totalling 1.04GiB
# 2021-12-07 01:11:55.788953: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 2949120000 totalling 8.24GiB
# 2021-12-07 01:11:55.788966: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 9.42GiB
# 2021-12-07 01:11:55.788979: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 15477595136 memory_limit_: 15477595200 available bytes: 64 curr_region_allocation_bytes_: 30955190784
# 2021-12-07 01:11:55.788997: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                     15477595200
# InUse:                     10119253760
# MaxInUse:                  10119253760
# NumAllocs:                        1399
# MaxAllocSize:               2965897216
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2021-12-07 01:11:55.789084: W tensorflow/core/common_runtime/bfc_allocator.cc:441] *__**_____________*****************************************************************_________________
# 2021-12-07 01:11:55.789154: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at fused_batch_norm_op.cc:1302 : Resource exhausted: OOM when allocating tensor with shape[1024,32,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_27381/3988123256.py in <module>
#       8                         validation_steps = val_dataset_size//batch_size,
#       9                         initial_epoch = initial_epoch,
# ---> 10                         verbose = 1)
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     886         # Lifting succeeded, so variables are initialized and we can run the
#     887         # stateless function.
# --> 888         return self._stateless_fn(*args, **kwds)
#     889     else:
#     890       _, _, _, filtered_flat_args = \
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/jun_env/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted:  OOM when allocating tensor with shape[1024,32,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model/bbn_stage1_block2_dw_bn/FusedBatchNormV3 (defined at tmp/ipykernel_27381/3988123256.py:10) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[compute_loss/PartitionedCall/Equal/_34]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted:  OOM when allocating tensor with shape[1024,32,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model/bbn_stage1_block2_dw_bn/FusedBatchNormV3 (defined at tmp/ipykernel_27381/3988123256.py:10) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_17615]
#
# Function call stack:
# train_function -> train_function

# %%
# tf.keras.models.save_model(model, '/root/mobilenet_v2_ssdlite_keras/epoch1500_model.h5')

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# out of memory

import tensorflow as tf

with tf.Graph().as_default():
    gpu_options = tf.compat.v1.GPUOptions(allow_growth=True)
