# %% [markdown]
# # DCGAN to generate face images
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2019/04/29<br>
# **Last modified:** 2021/01/01<br>
# **Description:** A simple DCGAN trained using `fit()` by overriding `train_step` on CelebA images.

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np



import matplotlib.pyplot as plt
import os
import gdown
from zipfile import ZipFile
# Out:
# 2021-12-04 02:52:33.922870: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2021-12-04 02:52:35.099036: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-12-04 02:52:35.182112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.183586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.759GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-12-04 02:52:35.183650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.184331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:0b:00.0 name: NVIDIA GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.759GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-12-04 02:52:35.184345: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-12-04 02:52:35.185380: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-12-04 02:52:35.186446: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-12-04 02:52:35.186616: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-12-04 02:52:35.187623: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-12-04 02:52:35.188220: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-12-04 02:52:35.219968: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-12-04 02:52:35.220221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.221813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.223365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.224885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.226362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2021-12-04 02:52:35.227414: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-04 02:52:35.250369: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3199630000 Hz
# 2021-12-04 02:52:35.251577: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x564545ec9f80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-12-04 02:52:35.251625: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-12-04 02:52:35.440617: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.466032: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.466860: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5645484ddca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-12-04 02:52:35.466877: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2021-12-04 02:52:35.466882: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2021-12-04 02:52:35.468034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.468632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.759GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-12-04 02:52:35.468705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.469283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:0b:00.0 name: NVIDIA GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.759GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-12-04 02:52:35.469311: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-12-04 02:52:35.469335: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-12-04 02:52:35.469349: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-12-04 02:52:35.469362: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-12-04 02:52:35.469375: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-12-04 02:52:35.469389: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-12-04 02:52:35.469410: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-12-04 02:52:35.469495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.478757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.479957: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.481146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:35.482241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2021-12-04 02:52:35.482304: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-12-04 02:52:36.022423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-04 02:52:36.022460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0 1
# 2021-12-04 02:52:36.022471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N Y
# 2021-12-04 02:52:36.022474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 1:   Y N
# 2021-12-04 02:52:36.022731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:36.023229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:36.023695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:36.024133: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7412 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:0a:00.0, compute capability: 6.1)
# 2021-12-04 02:52:36.024794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-04 02:52:36.025326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 7422 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:0b:00.0, compute capability: 6.1)

# %% [markdown]
# ## Prepare data
# resized to 64x64.

# %% [markdown]
# Create a dataset from our folder, and rescale the images to the [0-1] range:

# %%
dataset = keras.preprocessing.image_dataset_from_directory(
    "/root/data/shin/make/", label_mode=None, image_size=(64, 64), batch_size=32
)
dataset = dataset.map(lambda x: x / 255.0)
# Out:
# Found 595 files belonging to 1 classes.

# %% [markdown]
# Let's display a sample image:

# %%
for x in dataset:
    plt.axis("off")
    plt.imshow((x.numpy() * 255).astype("int32")[0])
    break

# %% [markdown]
# ## Create the discriminator
#
# It maps a 64x64 image to a binary classification score.

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=(64, 64, 3)),
        layers.Conv2D(64, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        3136
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       131200
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         262272
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 8193
# =================================================================
# Total params: 404,801
# Trainable params: 404,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Create the generator
#
# It mirrors the discriminator, replacing `Conv2D` layers with `Conv2DTranspose` layers.

# %%
latent_dim = 128

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(8 * 8 * 128),
        layers.Reshape((8, 8, 128)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(256, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(512, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(3, kernel_size=5, padding="same", activation="sigmoid"),
    ],
    name="generator",
)
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8192)              1056768
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 16, 16, 128)       262272
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       524544
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 64, 64, 512)       2097664
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 3)         38403
# =================================================================
# Total params: 3,979,651
# Trainable params: 3,979,651
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Override `train_step`

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images
        combined_images = tf.concat([generated_images, real_images], axis=0)

        # Assemble labels discriminating real from fake images
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        )
        # Add random noise to the labels - important trick!
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        # Sample random points in the latent space
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Assemble labels that say "all real images"
        misleading_labels = tf.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %% [markdown]
# ## Create a callback that periodically saves generated images

# %%
g_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
d_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)

# %%
gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=d_optimizer,
    g_optimizer=g_optimizer,
    loss_fn=keras.losses.BinaryCrossentropy(),
)

# %%
checkpoint_dir = './dcgan_training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=g_optimizer,
                                 discriminator_optimizer=d_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=128):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        epoch += 212011
        if epoch % 50 == 0:
            os.mkdir(f'/root/data/shin/dcgan/epoch_{epoch}')
            for i in range(self.num_img):
                img = keras.preprocessing.image.array_to_img(generated_images[i])
                img.save(f"/root/data/shin/dcgan/epoch_{epoch}/{i}.jpg")
            checkpoint.save(file_prefix = checkpoint_prefix)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# ## Train the end-to-end model

# %%
gan.fit(
    dataset, epochs=10000, callbacks=[GANMonitor(num_img=10, latent_dim=latent_dim)]
)
# Out:
# Epoch 1/10000
# 2021-12-04 02:53:53.288182: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-12-04 02:53:53.717937: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 19/19 [==============================] - 5s 239ms/step - d_loss: -1.0958 - g_loss: 136.2265
# Epoch 2/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2498 - g_loss: 145.6256
# Epoch 3/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.3303 - g_loss: 143.9364
# Epoch 4/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1237 - g_loss: 130.5542
# Epoch 5/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1981 - g_loss: 136.6091
# Epoch 6/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1288 - g_loss: 134.0435
# Epoch 7/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0156 - g_loss: 129.2965
# Epoch 8/10000
# 19/19 [==============================] - 4s 200ms/step - d_loss: -0.9719 - g_loss: 128.2226
# Epoch 9/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1008 - g_loss: 126.0691
# Epoch 10/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1074 - g_loss: 129.9750
# Epoch 11/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0503 - g_loss: 124.5386
# Epoch 12/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.3420 - g_loss: 145.8382
# Epoch 13/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4089 - g_loss: 157.2139
# Epoch 14/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.4259 - g_loss: 154.2168
# Epoch 15/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4934 - g_loss: 146.8103
# Epoch 16/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2196 - g_loss: 135.6981
# Epoch 17/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.3328 - g_loss: 136.1775
# Epoch 18/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1080 - g_loss: 130.5065
# Epoch 19/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1593 - g_loss: 128.1846
# Epoch 20/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1985 - g_loss: 136.7166
# Epoch 21/10000
# 19/19 [==============================] - 4s 200ms/step - d_loss: -1.3105 - g_loss: 138.6490
# Epoch 22/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3429 - g_loss: 142.0291
# Epoch 23/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.4421 - g_loss: 114.9345
# Epoch 24/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.7200 - g_loss: 125.8218
# Epoch 25/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.7214 - g_loss: 125.5491
# Epoch 26/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2710 - g_loss: 131.6046
# Epoch 27/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2729 - g_loss: 140.1344
# Epoch 28/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2062 - g_loss: 132.0772
# Epoch 29/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.7680 - g_loss: 121.1862
# Epoch 30/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0321 - g_loss: 134.4684
# Epoch 31/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1446 - g_loss: 137.2442
# Epoch 32/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1846 - g_loss: 132.9449
# Epoch 33/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2489 - g_loss: 137.6914
# Epoch 34/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0457 - g_loss: 134.8880
# Epoch 35/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0542 - g_loss: 130.9095
# Epoch 36/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1826 - g_loss: 135.4278
# Epoch 37/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0331 - g_loss: 130.4460
# Epoch 38/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8789 - g_loss: 129.5567
# Epoch 39/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1272 - g_loss: 131.8709
# Epoch 40/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.3233 - g_loss: 140.5819
# Epoch 41/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.7773 - g_loss: 121.2584
# Epoch 42/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2361 - g_loss: 151.4281
# Epoch 43/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1573 - g_loss: 136.1566
# Epoch 44/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3027 - g_loss: 134.8459
# Epoch 45/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2997 - g_loss: 137.1914
# Epoch 46/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0522 - g_loss: 131.4899
# Epoch 47/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0310 - g_loss: 135.4818
# Epoch 48/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2488 - g_loss: 133.3195
# Epoch 49/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.8730 - g_loss: 132.1776
# Epoch 50/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1957 - g_loss: 140.9550
# Epoch 51/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2759 - g_loss: 141.0295
# Epoch 52/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.2018 - g_loss: 135.7604
# Epoch 53/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0421 - g_loss: 128.8475
# Epoch 54/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2818 - g_loss: 138.4380
# Epoch 55/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0185 - g_loss: 130.2597
# Epoch 56/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2387 - g_loss: 136.5386
# Epoch 57/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1009 - g_loss: 136.0269
# Epoch 58/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.7020 - g_loss: 123.6786
# Epoch 59/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0668 - g_loss: 131.0138
# Epoch 60/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1236 - g_loss: 130.0033
# Epoch 61/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1757 - g_loss: 139.0442
# Epoch 62/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2163 - g_loss: 138.0615
# Epoch 63/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.3222 - g_loss: 110.7020
# Epoch 64/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.8355 - g_loss: 130.6266
# Epoch 65/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: 0.0817 - g_loss: 96.4554
# Epoch 66/10000
# 19/19 [==============================] - 4s 201ms/step - d_loss: -0.5813 - g_loss: 121.1919
# Epoch 67/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.8618 - g_loss: 122.1079
# Epoch 68/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3670 - g_loss: 143.0011
# Epoch 69/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.4883 - g_loss: 149.7450
# Epoch 70/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4281 - g_loss: 148.2419
# Epoch 71/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3162 - g_loss: 139.7018
# Epoch 72/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.9247 - g_loss: 128.6279
# Epoch 73/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1327 - g_loss: 132.0901
# Epoch 74/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2249 - g_loss: 140.0900
# Epoch 75/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2038 - g_loss: 136.7716
# Epoch 76/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9801 - g_loss: 128.5807
# Epoch 77/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0909 - g_loss: 131.0859
# Epoch 78/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3228 - g_loss: 142.6626
# Epoch 79/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.3586 - g_loss: 141.2738
# Epoch 80/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9741 - g_loss: 131.1647
# Epoch 81/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0986 - g_loss: 138.2485
# Epoch 82/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2501 - g_loss: 139.0275
# Epoch 83/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1437 - g_loss: 132.5652
# Epoch 84/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0458 - g_loss: 131.6302
# Epoch 85/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3203 - g_loss: 139.2688
# Epoch 86/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.2916 - g_loss: 145.2882
# Epoch 87/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0762 - g_loss: 141.5318
# Epoch 88/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2327 - g_loss: 138.3729
# Epoch 89/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4964 - g_loss: 144.4716
# Epoch 90/10000
# 19/19 [==============================] - 4s 212ms/step - d_loss: -1.4818 - g_loss: 146.3586
# Epoch 91/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3730 - g_loss: 149.7954
# Epoch 92/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2041 - g_loss: 138.5642
# Epoch 93/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.2744 - g_loss: 137.5319
# Epoch 94/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3130 - g_loss: 136.5439
# Epoch 95/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1861 - g_loss: 137.1303
# Epoch 96/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.1152 - g_loss: 133.1730
# Epoch 97/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1955 - g_loss: 143.2327
# Epoch 98/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2773 - g_loss: 140.7097
# Epoch 99/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8029 - g_loss: 121.4078
# Epoch 100/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1351 - g_loss: 141.7495
# Epoch 101/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3011 - g_loss: 147.9939
# Epoch 102/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3461 - g_loss: 143.2614
# Epoch 103/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3239 - g_loss: 142.9192
# Epoch 104/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.7133 - g_loss: 121.2406
# Epoch 105/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.9754 - g_loss: 132.8793
# Epoch 106/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2900 - g_loss: 141.8611
# Epoch 107/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2466 - g_loss: 140.6800
# Epoch 108/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.4858 - g_loss: 145.7754
# Epoch 109/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.5186 - g_loss: 154.3702
# Epoch 110/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3133 - g_loss: 144.6169
# Epoch 111/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1590 - g_loss: 144.0999
# Epoch 112/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9513 - g_loss: 122.0381
# Epoch 113/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1485 - g_loss: 136.0702
# Epoch 114/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2454 - g_loss: 141.8120
# Epoch 115/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.7701 - g_loss: 130.0708
# Epoch 116/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.8934 - g_loss: 124.5840
# Epoch 117/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.7862 - g_loss: 127.5529
# Epoch 118/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.4574 - g_loss: 149.1595
# Epoch 119/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3110 - g_loss: 141.9966
# Epoch 120/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.8419 - g_loss: 125.8459
# Epoch 121/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.8061 - g_loss: 125.9787
# Epoch 122/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0265 - g_loss: 131.5380
# Epoch 123/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1846 - g_loss: 131.6309
# Epoch 124/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.6577 - g_loss: 119.6577
# Epoch 125/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.8666 - g_loss: 126.9013
# Epoch 126/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1629 - g_loss: 134.0161
# Epoch 127/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2118 - g_loss: 143.6347
# Epoch 128/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2649 - g_loss: 143.3727
# Epoch 129/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3184 - g_loss: 137.9214
# Epoch 130/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0799 - g_loss: 140.9243
# Epoch 131/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.6915 - g_loss: 123.8969
# Epoch 132/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9615 - g_loss: 134.3020
# Epoch 133/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2135 - g_loss: 132.7528
# Epoch 134/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0981 - g_loss: 135.3168
# Epoch 135/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0034 - g_loss: 133.9125
# Epoch 136/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9776 - g_loss: 130.6387
# Epoch 137/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.9335 - g_loss: 130.7234
# Epoch 138/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2560 - g_loss: 144.2663
# Epoch 139/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.3303 - g_loss: 153.6791
# Epoch 140/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2570 - g_loss: 147.0795
# Epoch 141/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3583 - g_loss: 146.0559
# Epoch 142/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1245 - g_loss: 132.8475
# Epoch 143/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4070 - g_loss: 141.6126
# Epoch 144/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.9211 - g_loss: 123.8914
# Epoch 145/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.8367 - g_loss: 129.4310
# Epoch 146/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.9107 - g_loss: 126.5118
# Epoch 147/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.6067 - g_loss: 122.2580
# Epoch 148/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.8177 - g_loss: 123.5912
# Epoch 149/10000
# 19/19 [==============================] - 4s 201ms/step - d_loss: -1.0308 - g_loss: 126.3391
# Epoch 150/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2183 - g_loss: 134.3667
# Epoch 151/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1784 - g_loss: 137.5854
# Epoch 152/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.9373 - g_loss: 129.9028
# Epoch 153/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0096 - g_loss: 133.6607
# Epoch 154/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1484 - g_loss: 134.4374
# Epoch 155/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9755 - g_loss: 133.7604
# Epoch 156/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1755 - g_loss: 136.5741
# Epoch 157/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2521 - g_loss: 136.8237
# Epoch 158/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1604 - g_loss: 143.4084
# Epoch 159/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1071 - g_loss: 135.3716
# Epoch 160/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.1385 - g_loss: 136.5387
# Epoch 161/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1128 - g_loss: 140.0144
# Epoch 162/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0699 - g_loss: 131.9947
# Epoch 163/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.8312 - g_loss: 126.5796
# Epoch 164/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0391 - g_loss: 128.9304
# Epoch 165/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.8698 - g_loss: 131.0788
# Epoch 166/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.1986 - g_loss: 109.2721
# Epoch 167/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.3748 - g_loss: 117.0657
# Epoch 168/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0555 - g_loss: 138.3005
# Epoch 169/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0766 - g_loss: 130.3645
# Epoch 170/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2085 - g_loss: 130.9815
# Epoch 171/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3084 - g_loss: 142.5323
# Epoch 172/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3051 - g_loss: 139.5293
# Epoch 173/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2155 - g_loss: 137.0759
# Epoch 174/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4190 - g_loss: 154.8918
# Epoch 175/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.4736 - g_loss: 152.5730
# Epoch 176/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.5718 - g_loss: 162.5921
# Epoch 177/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2288 - g_loss: 145.9955
# Epoch 178/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0214 - g_loss: 139.8370
# Epoch 179/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2046 - g_loss: 142.1365
# Epoch 180/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3253 - g_loss: 138.1466
# Epoch 181/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3831 - g_loss: 141.2446
# Epoch 182/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0929 - g_loss: 136.0493
# Epoch 183/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1652 - g_loss: 143.7145
# Epoch 184/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2728 - g_loss: 140.6564
# Epoch 185/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0126 - g_loss: 135.1389
# Epoch 186/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.9477 - g_loss: 129.4536
# Epoch 187/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0051 - g_loss: 134.6059
# Epoch 188/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.9467 - g_loss: 132.9733
# Epoch 189/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0594 - g_loss: 138.0382
# Epoch 190/10000
# 19/19 [==============================] - 4s 211ms/step - d_loss: -0.9840 - g_loss: 128.8969
# Epoch 191/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9926 - g_loss: 130.5206
# Epoch 192/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2372 - g_loss: 135.4678
# Epoch 193/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0724 - g_loss: 128.8131
# Epoch 194/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.8274 - g_loss: 127.3833
# Epoch 195/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2381 - g_loss: 136.6345
# Epoch 196/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -0.5775 - g_loss: 122.4896
# Epoch 197/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9410 - g_loss: 131.9309
# Epoch 198/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9008 - g_loss: 128.6720
# Epoch 199/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9377 - g_loss: 127.3145
# Epoch 200/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1424 - g_loss: 135.2371
# Epoch 201/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0230 - g_loss: 126.3364
# Epoch 202/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.4394 - g_loss: 128.1783
# Epoch 203/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9850 - g_loss: 132.8328
# Epoch 204/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2418 - g_loss: 140.9927
# Epoch 205/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.9319 - g_loss: 135.4859
# Epoch 206/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1613 - g_loss: 140.1279
# Epoch 207/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1396 - g_loss: 141.1673
# Epoch 208/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0008 - g_loss: 124.8844
# Epoch 209/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9064 - g_loss: 128.2992
# Epoch 210/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2953 - g_loss: 138.4218
# Epoch 211/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0827 - g_loss: 138.3632
# Epoch 212/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.6866 - g_loss: 124.9920
# Epoch 213/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1288 - g_loss: 137.8386
# Epoch 214/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3616 - g_loss: 143.8846
# Epoch 215/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1568 - g_loss: 136.2390
# Epoch 216/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4068 - g_loss: 146.1978
# Epoch 217/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3919 - g_loss: 147.7551
# Epoch 218/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2818 - g_loss: 142.9129
# Epoch 219/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2815 - g_loss: 145.9292
# Epoch 220/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0574 - g_loss: 135.8125
# Epoch 221/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0934 - g_loss: 138.4162
# Epoch 222/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9418 - g_loss: 134.6155
# Epoch 223/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.3226 - g_loss: 112.6052
# Epoch 224/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.6062 - g_loss: 125.3777
# Epoch 225/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1168 - g_loss: 137.9477
# Epoch 226/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2579 - g_loss: 141.3199
# Epoch 227/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2116 - g_loss: 135.8751
# Epoch 228/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2060 - g_loss: 136.1430
# Epoch 229/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3552 - g_loss: 140.6744
# Epoch 230/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2226 - g_loss: 142.0975
# Epoch 231/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9021 - g_loss: 128.1670
# Epoch 232/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.9966 - g_loss: 135.3380
# Epoch 233/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4702 - g_loss: 149.1863
# Epoch 234/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2929 - g_loss: 138.5941
# Epoch 235/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2208 - g_loss: 142.2387
# Epoch 236/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1000 - g_loss: 136.2045
# Epoch 237/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3335 - g_loss: 137.3423
# Epoch 238/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2041 - g_loss: 138.9073
# Epoch 239/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2936 - g_loss: 145.2915
# Epoch 240/10000
# 19/19 [==============================] - 4s 211ms/step - d_loss: -1.3934 - g_loss: 141.2500
# Epoch 241/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3115 - g_loss: 139.8365
# Epoch 242/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.6269 - g_loss: 124.8715
# Epoch 243/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3103 - g_loss: 145.3838
# Epoch 244/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2956 - g_loss: 145.6204
# Epoch 245/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0587 - g_loss: 139.6694
# Epoch 246/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.3264 - g_loss: 127.1550
# Epoch 247/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.6529 - g_loss: 131.5221
# Epoch 248/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1414 - g_loss: 142.7826
# Epoch 249/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1415 - g_loss: 139.2820
# Epoch 250/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2338 - g_loss: 143.9457
# Epoch 251/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2875 - g_loss: 141.0412
# Epoch 252/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1461 - g_loss: 138.9650
# Epoch 253/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1708 - g_loss: 137.9068
# Epoch 254/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0933 - g_loss: 133.4003
# Epoch 255/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.1767 - g_loss: 141.5796
# Epoch 256/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3619 - g_loss: 148.7862
# Epoch 257/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3153 - g_loss: 145.8512
# Epoch 258/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4136 - g_loss: 144.5442
# Epoch 259/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2356 - g_loss: 139.3504
# Epoch 260/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2692 - g_loss: 139.9500
# Epoch 261/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3113 - g_loss: 137.9368
# Epoch 262/10000
# 19/19 [==============================] - 4s 199ms/step - d_loss: -1.0015 - g_loss: 133.6757
# Epoch 263/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.8481 - g_loss: 126.5012
# Epoch 264/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8562 - g_loss: 122.9001
# Epoch 265/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.8208 - g_loss: 125.9497
# Epoch 266/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0300 - g_loss: 135.1319
# Epoch 267/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.6996 - g_loss: 122.2960
# Epoch 268/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0013 - g_loss: 133.9830
# Epoch 269/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3108 - g_loss: 139.1979
# Epoch 270/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1325 - g_loss: 133.9965
# Epoch 271/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0886 - g_loss: 129.5368
# Epoch 272/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1540 - g_loss: 143.8418
# Epoch 273/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1814 - g_loss: 143.6487
# Epoch 274/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3189 - g_loss: 142.1948
# Epoch 275/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.2509 - g_loss: 139.4097
# Epoch 276/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2147 - g_loss: 137.2888
# Epoch 277/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3220 - g_loss: 146.1583
# Epoch 278/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2564 - g_loss: 139.2656
# Epoch 279/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3744 - g_loss: 144.8674
# Epoch 280/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1883 - g_loss: 139.1059
# Epoch 281/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0909 - g_loss: 133.8771
# Epoch 282/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.9972 - g_loss: 134.2861
# Epoch 283/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2055 - g_loss: 132.8231
# Epoch 284/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3341 - g_loss: 144.3593
# Epoch 285/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1916 - g_loss: 141.2676
# Epoch 286/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5102 - g_loss: 156.6182
# Epoch 287/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1713 - g_loss: 142.5788
# Epoch 288/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.7581 - g_loss: 124.9502
# Epoch 289/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3832 - g_loss: 139.5187
# Epoch 290/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -0.9944 - g_loss: 134.9440
# Epoch 291/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1007 - g_loss: 133.8371
# Epoch 292/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1323 - g_loss: 140.8491
# Epoch 293/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0372 - g_loss: 134.5174
# Epoch 294/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1341 - g_loss: 141.8314
# Epoch 295/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.9219 - g_loss: 133.7573
# Epoch 296/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -0.9658 - g_loss: 132.6829
# Epoch 297/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.3492 - g_loss: 137.6688
# Epoch 298/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4845 - g_loss: 159.6986
# Epoch 299/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2946 - g_loss: 143.1860
# Epoch 300/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4094 - g_loss: 153.2432
# Epoch 301/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4156 - g_loss: 151.5359
# Epoch 302/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3794 - g_loss: 159.5312
# Epoch 303/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3019 - g_loss: 138.2126
# Epoch 304/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.3255 - g_loss: 141.8702
# Epoch 305/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3841 - g_loss: 145.2194
# Epoch 306/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2274 - g_loss: 142.9246
# Epoch 307/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2011 - g_loss: 137.4547
# Epoch 308/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3889 - g_loss: 147.1318
# Epoch 309/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3134 - g_loss: 143.5842
# Epoch 310/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3458 - g_loss: 145.7388
# Epoch 311/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3610 - g_loss: 139.3429
# Epoch 312/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3198 - g_loss: 142.7101
# Epoch 313/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1378 - g_loss: 139.6788
# Epoch 314/10000
# 19/19 [==============================] - 4s 199ms/step - d_loss: -1.1494 - g_loss: 138.4795
# Epoch 315/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2526 - g_loss: 143.8241
# Epoch 316/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2579 - g_loss: 146.1675
# Epoch 317/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1964 - g_loss: 138.8845
# Epoch 318/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3011 - g_loss: 151.4113
# Epoch 319/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4179 - g_loss: 155.8025
# Epoch 320/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -0.9761 - g_loss: 134.3083
# Epoch 321/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1705 - g_loss: 143.4008
# Epoch 322/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8170 - g_loss: 132.0336
# Epoch 323/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0603 - g_loss: 138.2534
# Epoch 324/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2279 - g_loss: 141.8222
# Epoch 325/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3751 - g_loss: 139.4378
# Epoch 326/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3724 - g_loss: 145.3374
# Epoch 327/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1000 - g_loss: 133.6733
# Epoch 328/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.2512 - g_loss: 118.0299
# Epoch 329/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.2939 - g_loss: 115.0047
# Epoch 330/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.9576 - g_loss: 127.1698
# Epoch 331/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9211 - g_loss: 129.8611
# Epoch 332/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.9679 - g_loss: 127.3145
# Epoch 333/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2268 - g_loss: 144.3231
# Epoch 334/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3748 - g_loss: 147.2687
# Epoch 335/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2899 - g_loss: 144.2575
# Epoch 336/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.6191 - g_loss: 158.4327
# Epoch 337/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.1304 - g_loss: 142.6471
# Epoch 338/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0307 - g_loss: 134.8098
# Epoch 339/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.1166 - g_loss: 140.9932
# Epoch 340/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3402 - g_loss: 145.2381
# Epoch 341/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2254 - g_loss: 142.2723
# Epoch 342/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.0203 - g_loss: 139.4615
# Epoch 343/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0866 - g_loss: 137.9861
# Epoch 344/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8559 - g_loss: 128.5087
# Epoch 345/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -0.7640 - g_loss: 129.8366
# Epoch 346/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0150 - g_loss: 137.1887
# Epoch 347/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: 0.2583 - g_loss: 107.3192
# Epoch 348/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -0.8141 - g_loss: 128.2388
# Epoch 349/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -0.9848 - g_loss: 130.3885
# Epoch 350/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0754 - g_loss: 137.1028
# Epoch 351/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.4714 - g_loss: 120.8393
# Epoch 352/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0571 - g_loss: 134.4961
# Epoch 353/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3422 - g_loss: 137.8969
# Epoch 354/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1435 - g_loss: 138.5777
# Epoch 355/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4220 - g_loss: 146.4190
# Epoch 356/10000
# 19/19 [==============================] - 4s 200ms/step - d_loss: -1.2788 - g_loss: 141.0156
# Epoch 357/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1436 - g_loss: 134.2170
# Epoch 358/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.0338 - g_loss: 136.3120
# Epoch 359/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0970 - g_loss: 140.0153
# Epoch 360/10000
# 19/19 [==============================] - 4s 201ms/step - d_loss: -1.2921 - g_loss: 140.1556
# Epoch 361/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.2851 - g_loss: 139.5262
# Epoch 362/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2907 - g_loss: 139.4883
# Epoch 363/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0786 - g_loss: 140.6466
# Epoch 364/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1941 - g_loss: 148.1183
# Epoch 365/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2913 - g_loss: 147.8629
# Epoch 366/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0879 - g_loss: 135.7762
# Epoch 367/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2324 - g_loss: 150.1355
# Epoch 368/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2150 - g_loss: 146.9446
# Epoch 369/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1620 - g_loss: 140.1256
# Epoch 370/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2911 - g_loss: 145.3320
# Epoch 371/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2899 - g_loss: 144.5815
# Epoch 372/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1725 - g_loss: 141.1592
# Epoch 373/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1847 - g_loss: 142.7247
# Epoch 374/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2539 - g_loss: 143.4940
# Epoch 375/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.9189 - g_loss: 128.1139
# Epoch 376/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.7383 - g_loss: 124.4543
# Epoch 377/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.2203 - g_loss: 147.0411
# Epoch 378/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4534 - g_loss: 147.0255
# Epoch 379/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2554 - g_loss: 144.5958
# Epoch 380/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.2971 - g_loss: 145.6732
# Epoch 381/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0983 - g_loss: 141.5024
# Epoch 382/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9315 - g_loss: 131.3272
# Epoch 383/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.8317 - g_loss: 125.0472
# Epoch 384/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.5749 - g_loss: 126.3129
# Epoch 385/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9697 - g_loss: 136.8756
# Epoch 386/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.0726 - g_loss: 137.9376
# Epoch 387/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1419 - g_loss: 137.1119
# Epoch 388/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.6450 - g_loss: 117.2544
# Epoch 389/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -0.8979 - g_loss: 135.4823
# Epoch 390/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.0046 - g_loss: 141.5560
# Epoch 391/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1414 - g_loss: 141.0620
# Epoch 392/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0768 - g_loss: 142.8010
# Epoch 393/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.4282 - g_loss: 149.4845
# Epoch 394/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1832 - g_loss: 141.7195
# Epoch 395/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2137 - g_loss: 137.5261
# Epoch 396/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.0229 - g_loss: 130.8559
# Epoch 397/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.6982 - g_loss: 120.6062
# Epoch 398/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.8516 - g_loss: 137.7795
# Epoch 399/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1804 - g_loss: 141.4516
# Epoch 400/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0983 - g_loss: 139.5970
# Epoch 401/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2891 - g_loss: 146.8897
# Epoch 402/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2596 - g_loss: 142.6493
# Epoch 403/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1624 - g_loss: 137.8799
# Epoch 404/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4068 - g_loss: 137.5611
# Epoch 405/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2556 - g_loss: 147.2954
# Epoch 406/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0333 - g_loss: 135.6385
# Epoch 407/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2553 - g_loss: 142.7142
# Epoch 408/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2019 - g_loss: 141.8230
# Epoch 409/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0217 - g_loss: 131.7156
# Epoch 410/10000
# 19/19 [==============================] - 4s 201ms/step - d_loss: -1.2518 - g_loss: 145.3597
# Epoch 411/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1692 - g_loss: 147.6836
# Epoch 412/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3334 - g_loss: 151.2727
# Epoch 413/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4352 - g_loss: 149.8147
# Epoch 414/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1536 - g_loss: 141.8500
# Epoch 415/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.6537 - g_loss: 122.7007
# Epoch 416/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.8972 - g_loss: 126.5327
# Epoch 417/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0379 - g_loss: 134.9135
# Epoch 418/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1901 - g_loss: 144.2643
# Epoch 419/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9616 - g_loss: 131.2287
# Epoch 420/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.2352 - g_loss: 142.5352
# Epoch 421/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.0867 - g_loss: 140.8557
# Epoch 422/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0229 - g_loss: 137.9585
# Epoch 423/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1203 - g_loss: 142.1747
# Epoch 424/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -0.8558 - g_loss: 126.8689
# Epoch 425/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0793 - g_loss: 137.2086
# Epoch 426/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.8564 - g_loss: 131.5198
# Epoch 427/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.0937 - g_loss: 128.3909
# Epoch 428/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.2315 - g_loss: 145.1474
# Epoch 429/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2351 - g_loss: 143.7370
# Epoch 430/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.4468 - g_loss: 164.1715
# Epoch 431/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.8347 - g_loss: 128.9588
# Epoch 432/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.8910 - g_loss: 131.9461
# Epoch 433/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1252 - g_loss: 141.6673
# Epoch 434/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0149 - g_loss: 135.3653
# Epoch 435/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2104 - g_loss: 142.9588
# Epoch 436/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4014 - g_loss: 145.4090
# Epoch 437/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3908 - g_loss: 144.8553
# Epoch 438/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.4453 - g_loss: 152.3467
# Epoch 439/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3728 - g_loss: 144.8056
# Epoch 440/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.0788 - g_loss: 139.6503
# Epoch 441/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1137 - g_loss: 139.5993
# Epoch 442/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0366 - g_loss: 140.7842
# Epoch 443/10000
# ...
# Epoch 1425/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3208 - g_loss: 159.0946
# Epoch 1426/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4221 - g_loss: 156.5736
# Epoch 1427/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.5308 - g_loss: 156.1992
# Epoch 1428/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.6895 - g_loss: 166.5462
# Epoch 1429/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.5201 - g_loss: 168.8178
# Epoch 1430/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0539 - g_loss: 154.4551
# Epoch 1431/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3735 - g_loss: 164.0326
# Epoch 1432/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.6512 - g_loss: 164.5841
# Epoch 1433/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.2932 - g_loss: 154.6421
# Epoch 1434/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.5370 - g_loss: 160.5005
# Epoch 1435/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4685 - g_loss: 161.8466
# Epoch 1436/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2748 - g_loss: 159.4741
# Epoch 1437/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.8775 - g_loss: 143.7121
# Epoch 1438/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.0457 - g_loss: 138.8429
# Epoch 1439/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.9055 - g_loss: 142.5070
# Epoch 1440/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.7521 - g_loss: 136.3685
# Epoch 1441/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1839 - g_loss: 156.7269
# Epoch 1442/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.5545 - g_loss: 158.0446
# Epoch 1443/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3654 - g_loss: 158.9897
# Epoch 1444/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.6410 - g_loss: 168.3753
# Epoch 1445/10000
# 19/19 [==============================] - 4s 210ms/step - d_loss: -1.5249 - g_loss: 164.2944
# Epoch 1446/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4861 - g_loss: 172.2932
# Epoch 1447/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.5821 - g_loss: 163.9139
# Epoch 1448/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3866 - g_loss: 158.4436
# Epoch 1449/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4362 - g_loss: 163.5326
# Epoch 1450/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4366 - g_loss: 161.6229
# Epoch 1451/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1664 - g_loss: 150.1289
# Epoch 1452/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1540 - g_loss: 151.3865
# Epoch 1453/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1695 - g_loss: 157.3454
# Epoch 1454/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2848 - g_loss: 155.2089
# Epoch 1455/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.5600 - g_loss: 162.3936
# Epoch 1456/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1174 - g_loss: 158.3591
# Epoch 1457/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0261 - g_loss: 150.3988
# Epoch 1458/10000
# 19/19 [==============================] - 4s 211ms/step - d_loss: -1.4069 - g_loss: 154.5843
# Epoch 1459/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.2731 - g_loss: 161.7889
# Epoch 1460/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3847 - g_loss: 160.2638
# Epoch 1461/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5920 - g_loss: 165.2820
# Epoch 1462/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.5592 - g_loss: 166.0197
# Epoch 1463/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4525 - g_loss: 167.9648
# Epoch 1464/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5268 - g_loss: 166.4652
# Epoch 1465/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.6599 - g_loss: 164.8588
# Epoch 1466/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1524 - g_loss: 149.7036
# Epoch 1467/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1957 - g_loss: 152.7324
# Epoch 1468/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3001 - g_loss: 159.6881
# Epoch 1469/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4335 - g_loss: 164.3798
# Epoch 1470/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4376 - g_loss: 158.1028
# Epoch 1471/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.4109 - g_loss: 157.1901
# Epoch 1472/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.5048 - g_loss: 167.2462
# Epoch 1473/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4795 - g_loss: 166.5938
# Epoch 1474/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.0889 - g_loss: 149.4573
# Epoch 1475/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.8973 - g_loss: 136.5091
# Epoch 1476/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3598 - g_loss: 162.7663
# Epoch 1477/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.5117 - g_loss: 166.8871
# Epoch 1478/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2484 - g_loss: 157.2103
# Epoch 1479/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.5983 - g_loss: 166.7206
# Epoch 1480/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9255 - g_loss: 145.1186
# Epoch 1481/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0250 - g_loss: 145.6816
# Epoch 1482/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.8192 - g_loss: 143.0664
# Epoch 1483/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2945 - g_loss: 161.8729
# Epoch 1484/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1391 - g_loss: 159.5584
# Epoch 1485/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.5110 - g_loss: 169.4341
# Epoch 1486/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3727 - g_loss: 159.4266
# Epoch 1487/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.0607 - g_loss: 144.7692
# Epoch 1488/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3871 - g_loss: 160.1059
# Epoch 1489/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -0.9470 - g_loss: 143.1482
# Epoch 1490/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4512 - g_loss: 158.1674
# Epoch 1491/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3795 - g_loss: 161.7088
# Epoch 1492/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3380 - g_loss: 150.9627
# Epoch 1493/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0754 - g_loss: 148.1933
# Epoch 1494/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4255 - g_loss: 156.4700
# Epoch 1495/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4114 - g_loss: 163.8526
# Epoch 1496/10000
# 19/19 [==============================] - 4s 201ms/step - d_loss: -1.5450 - g_loss: 161.6585
# Epoch 1497/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4599 - g_loss: 157.2152
# Epoch 1498/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.7121 - g_loss: 168.6753
# Epoch 1499/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4756 - g_loss: 164.2465
# Epoch 1500/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4788 - g_loss: 159.9547
# Epoch 1501/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.5367 - g_loss: 163.2776
# Epoch 1502/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.7438 - g_loss: 181.1251
# Epoch 1503/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.8498 - g_loss: 176.0743
# Epoch 1504/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.8275 - g_loss: 172.0807
# Epoch 1505/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.1938 - g_loss: 153.6613
# Epoch 1506/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.4829 - g_loss: 157.1261
# Epoch 1507/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5539 - g_loss: 164.6274
# Epoch 1508/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2721 - g_loss: 160.1033
# Epoch 1509/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.3921 - g_loss: 169.7018
# Epoch 1510/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.6881 - g_loss: 172.2041
# Epoch 1511/10000
# 19/19 [==============================] - 4s 211ms/step - d_loss: -1.5730 - g_loss: 167.2913
# Epoch 1512/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2394 - g_loss: 144.9900
# Epoch 1513/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.6779 - g_loss: 138.3444
# Epoch 1514/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.1436 - g_loss: 149.3960
# Epoch 1515/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.3601 - g_loss: 155.0705
# Epoch 1516/10000
# 19/19 [==============================] - 4s 202ms/step - d_loss: -1.1756 - g_loss: 150.8997
# Epoch 1517/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.0007 - g_loss: 151.8695
# Epoch 1518/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.1189 - g_loss: 157.2985
# Epoch 1519/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3232 - g_loss: 163.3215
# Epoch 1520/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2192 - g_loss: 162.6342
# Epoch 1521/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2310 - g_loss: 156.6702
# Epoch 1522/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.1748 - g_loss: 155.3602
# Epoch 1523/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.2282 - g_loss: 157.1136
# Epoch 1524/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.4330 - g_loss: 156.3835
# Epoch 1525/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.2404 - g_loss: 153.5777
# Epoch 1526/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4758 - g_loss: 164.0250
# Epoch 1527/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3458 - g_loss: 161.4055
# Epoch 1528/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.5271 - g_loss: 164.3972
# Epoch 1529/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.5027 - g_loss: 159.6586
# Epoch 1530/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5052 - g_loss: 168.2205
# Epoch 1531/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4007 - g_loss: 161.8582
# Epoch 1532/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.4762 - g_loss: 160.1739
# Epoch 1533/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5300 - g_loss: 161.8419
# Epoch 1534/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2297 - g_loss: 151.6557
# Epoch 1535/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2693 - g_loss: 153.6510
# Epoch 1536/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.0447 - g_loss: 151.7151
# Epoch 1537/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1846 - g_loss: 160.8445
# Epoch 1538/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3264 - g_loss: 161.9731
# Epoch 1539/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -0.4911 - g_loss: 143.9167
# Epoch 1540/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -0.7787 - g_loss: 149.9638
# Epoch 1541/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -0.7983 - g_loss: 141.2672
# Epoch 1542/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1431 - g_loss: 155.5891
# Epoch 1543/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.3614 - g_loss: 168.8672
# Epoch 1544/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.4977 - g_loss: 167.9519
# Epoch 1545/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -0.8009 - g_loss: 139.3121
# Epoch 1546/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.1345 - g_loss: 153.2694
# Epoch 1547/10000
# 19/19 [==============================] - 4s 209ms/step - d_loss: -1.3250 - g_loss: 157.7412
# Epoch 1548/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.2806 - g_loss: 154.7862
# Epoch 1549/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.6004 - g_loss: 171.8342
# Epoch 1550/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3603 - g_loss: 160.2219
# Epoch 1551/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.6578 - g_loss: 164.1552
# Epoch 1552/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.4839 - g_loss: 168.3657
# Epoch 1553/10000
# 19/19 [==============================] - 4s 203ms/step - d_loss: -1.5200 - g_loss: 160.4966
# Epoch 1554/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.5862 - g_loss: 161.0971
# Epoch 1555/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.6491 - g_loss: 167.0924
# Epoch 1556/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.7032 - g_loss: 172.4559
# Epoch 1557/10000
# 19/19 [==============================] - 4s 200ms/step - d_loss: -1.4995 - g_loss: 162.8165
# Epoch 1558/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.5893 - g_loss: 170.7881
# Epoch 1559/10000
# 19/19 [==============================] - 4s 208ms/step - d_loss: -1.0416 - g_loss: 151.8473
# Epoch 1560/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3243 - g_loss: 161.6949
# Epoch 1561/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -1.3014 - g_loss: 155.1491
# Epoch 1562/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.2827 - g_loss: 158.4577
# Epoch 1563/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.5949 - g_loss: 166.7193
# Epoch 1564/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4069 - g_loss: 164.8463
# Epoch 1565/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.5782 - g_loss: 173.4797
# Epoch 1566/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.4896 - g_loss: 169.8155
# Epoch 1567/10000
# 19/19 [==============================] - 4s 206ms/step - d_loss: -0.9757 - g_loss: 143.5766
# Epoch 1568/10000
# 19/19 [==============================] - 4s 205ms/step - d_loss: -1.1274 - g_loss: 157.9676
# Epoch 1569/10000
# 19/19 [==============================] - 4s 207ms/step - d_loss: -1.3468 - g_loss: 165.0221
# Epoch 1570/10000
# 19/19 [==============================] - 4s 204ms/step - d_loss: -1.5618 - g_loss: 163.1111
# Epoch 1571/10000

# %% [markdown]
# Some of the last generated images around epoch 30
# (results keep improving after that):
#
# ![results](https://i.imgur.com/h5MtQZ7l.png)
